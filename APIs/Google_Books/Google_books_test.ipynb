# %%
import requests
import json
import pickle
import pandas as pd
import numpy as np
import time

# %% [markdown]
# ## Obtain sample information from request:

# %%
from .secrets import GOOGLE_KEY

# %%
response = requests.get('https://www.googleapis.com/books/v1/volumes?q=flowers+inauthor:keyes&key='+GOOGLE_KEY)

# %%
response
# Out:
# <Response [200]>

# %%
a = json.loads(response.text)

# %%
a
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 113,
#  'items': [{'kind': 'books#volume',
#    'id': 'gK98gXR8onwC',
#    'etag': 'ym8oWidtoE0',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/gK98gXR8onwC',
#    'volumeInfo': {'title': 'Flowers for Algernon',
#     'subtitle': 'A One-act Play',
#     'authors': ['David Rogers', 'Daniel Keyes'],
#     'publisher': 'Dramatic Publishing',
#     'publishedDate': '1969',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0871293870'},
#      {'type': 'ISBN_13', 'identifier': '9780871293879'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 32,
#     'printType': 'BOOK',
#     'averageRating': 5,
#     'ratingsCount': 1,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.0.2.0.preview.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=gK98gXR8onwC&pg=PA3&dq=flowers+inauthor:keyes&hl=&cd=1&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=gK98gXR8onwC&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Flowers_for_Algernon.html?hl=&id=gK98gXR8onwC'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=gK98gXR8onwC&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': '<b>FLOWERS</b> FOR ALGERNON A One-act Play For Four Men And One Woman” <br>\nCHARACTERS DR. STRAUSS . . . . . . . . . . . . . . . . . . . a young neurosurgeon <br>\nPROFESSOR NEMUR . . . . . . . . . . . . . . . . his older colleague ALICE KINNIAN&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': '_oG_iTxP1pIC',
#    'etag': 'Jes7pJi/E4Y',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/_oG_iTxP1pIC',
#    'volumeInfo': {'title': 'Flowers for Algernon',
#     'authors': ['Daniel Keyes'],
#     'publisher': 'Houghton Mifflin Harcourt',
#     'publishedDate': '2007-12-01',
#     'description': 'Oscar-winning film Charly starring Cliff Robertson and Claire Bloom-a mentally challenged man receives an operation that turns him into a genius...and introduces him to heartache.',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0547539630'},
#      {'type': 'ISBN_13', 'identifier': '9780547539638'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 304,
#     'printType': 'BOOK',
#     'categories': ['Fiction'],
#     'averageRating': 4,
#     'ratingsCount': 177,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': True,
#     'contentVersion': '1.12.11.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=_oG_iTxP1pIC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=_oG_iTxP1pIC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=_oG_iTxP1pIC&pg=PA225&dq=flowers+inauthor:keyes&hl=&cd=2&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=_oG_iTxP1pIC&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=_oG_iTxP1pIC'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 8.99, 'currencyCode': 'USD'},
#     'retailPrice': {'amount': 8.99, 'currencyCode': 'USD'},
#     'buyLink': 'https://play.google.com/store/books/details?id=_oG_iTxP1pIC&rdid=book-_oG_iTxP1pIC&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 8990000, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 8990000, 'currencyCode': 'USD'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Flowers_for_Algernon-sample-epub.acsm?id=_oG_iTxP1pIC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Flowers_for_Algernon-sample-pdf.acsm?id=_oG_iTxP1pIC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=_oG_iTxP1pIC&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False}},
#   {'kind': 'books#volume',
#    'id': 'wAUiAAAAMAAJ',
#    'etag': 'CEuD+avG3Fk',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/wAUiAAAAMAAJ',
#    'volumeInfo': {'title': 'Evan Dale',
#     'authors': ['F. Keyes'],
#     'publishedDate': '1864',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'NYPL:33433074876743'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 387,
#     'printType': 'BOOK',
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.1.1.0.full.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=wAUiAAAAMAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=wAUiAAAAMAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=wAUiAAAAMAAJ&pg=PA137&dq=flowers+inauthor:keyes&hl=&cd=3&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=wAUiAAAAMAAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=wAUiAAAAMAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FREE',
#     'isEbook': True,
#     'buyLink': 'https://play.google.com/store/books/details?id=wAUiAAAAMAAJ&rdid=book-wAUiAAAAMAAJ&rdot=1&source=gbs_api'},
#    'accessInfo': {'country': 'US',
#     'viewability': 'ALL_PAGES',
#     'embeddable': True,
#     'publicDomain': True,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False,
#      'downloadLink': 'http://books.google.com/books/download/Evan_Dale.epub?id=wAUiAAAAMAAJ&hl=&output=epub&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'downloadLink': 'http://books.google.com/books/download/Evan_Dale.pdf?id=wAUiAAAAMAAJ&hl=&output=pdf&sig=ACfU3U2Xg5OeqGIO0AvQ0NH19Kz80v0uRw&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=wAUiAAAAMAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'FULL_PUBLIC_DOMAIN',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'crushed on the unfeeling <b>flowers</b> of the carpet, take it tip tenderly, and curse the <br>\nfoot that spoiled it. For the rest of the evening Carleton was on an extensive <br>\nsearch of discovery for the missing <b>flower</b>. In truth, he was in great danger of <br>\nbecoming&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': 'wYB5PwAACAAJ',
#    'etag': 'nzRNkRjuXvg',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/wYB5PwAACAAJ',
#    'volumeInfo': {'title': 'Bloemen Voor Algernon',
#     'authors': ['Daniel Keyes'],
#     'publisher': 'Bantam Books',
#     'publishedDate': '1984-05-01',
#     'description': 'With more than five million copies sold, "Flowers for Algernon" is the beloved, classic story of a mentally disabled man whose experimental quest for intelligence mirrors that of Algernon, an extraordinary lab mouse. High school and older.',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0553169041'},
#      {'type': 'ISBN_13', 'identifier': '9780553169041'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 72,
#     'printType': 'BOOK',
#     'averageRating': 4,
#     'ratingsCount': 157,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=wYB5PwAACAAJ&dq=flowers+inauthor:keyes&hl=&cd=4&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=wYB5PwAACAAJ&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Bloemen_Voor_Algernon.html?hl=&id=wYB5PwAACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=wYB5PwAACAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'With more than five million copies sold, &quot;Flowers for Algernon&quot; is the beloved, classic story of a mentally disabled man whose experimental quest for intelligence mirrors that of Algernon, an extraordinary lab mouse. High school and older.'}},
#   {'kind': 'books#volume',
#    'id': 'jQxIAQAAMAAJ',
#    'etag': 'v3u/r482Yx0',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/jQxIAQAAMAAJ',
#    'volumeInfo': {'title': 'The Five Senses',
#     'authors': ['Angela Mary Keyes'],
#     'publishedDate': '1911',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'IOWA:31858006011708'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 252,
#     'printType': 'BOOK',
#     'categories': ['Senses and sensation'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'full-1.0.0',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=jQxIAQAAMAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=jQxIAQAAMAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=jQxIAQAAMAAJ&pg=PA203&dq=flowers+inauthor:keyes&hl=&cd=5&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=jQxIAQAAMAAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=jQxIAQAAMAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FREE',
#     'isEbook': True,
#     'buyLink': 'https://play.google.com/store/books/details?id=jQxIAQAAMAAJ&rdid=book-jQxIAQAAMAAJ&rdot=1&source=gbs_api'},
#    'accessInfo': {'country': 'US',
#     'viewability': 'ALL_PAGES',
#     'embeddable': True,
#     'publicDomain': True,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=jQxIAQAAMAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'FULL_PUBLIC_DOMAIN',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'In field and garden the <b>flowers</b> no longer stood forth gaily in their brightest colors. <br>\nButtercups and daisies bent on their ... “And O, Nell,” cried Ned, “there are no air <br>\nships taking callers from <b>flower</b> to <b>flower</b>.” “No,” said Nell, “perhaps it is too wet&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': 'xYK5oAEACAAJ',
#    'etag': 'UPnY+0ord50',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/xYK5oAEACAAJ',
#    'volumeInfo': {'title': 'Flowers for Algernon - Multiple Critical Perspectives',
#     'authors': ['Daniel Keyes'],
#     'publishedDate': '2011-01-01',
#     'description': 'Probe the depth and richness of your favorite titles and usher your students into an understanding of what really made us want to teach literature in the first place. Each guide offers clear and concise explanations of three different critical perspectives.',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1935467964'},
#      {'type': 'ISBN_13', 'identifier': '9781935467960'}],
#     'readingModes': {'text': False, 'image': False},
#     'printType': 'BOOK',
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=xYK5oAEACAAJ&dq=flowers+inauthor:keyes&hl=&cd=6&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=xYK5oAEACAAJ&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Flowers_for_Algernon_Multiple_Critical_P.html?hl=&id=xYK5oAEACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=xYK5oAEACAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Probe the depth and richness of your favorite titles and usher your students into an understanding of what really made us want to teach literature in the first place.'}},
#   {'kind': 'books#volume',
#    'id': 'LRlCAAAAYAAJ',
#    'etag': 'kU1SLj+zx1Q',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/LRlCAAAAYAAJ',
#    'volumeInfo': {'title': 'Some Environmental Factors Influencing Bud Formation, Abscission and Flower Production of Gardenias',
#     'authors': ['Curtis Gilbert Keyes'],
#     'publishedDate': '1946',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'CORNELL:31924002987646'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 190,
#     'printType': 'BOOK',
#     'categories': ['Gardenia'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.1.1.0.preview.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=LRlCAAAAYAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=LRlCAAAAYAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=LRlCAAAAYAAJ&q=flowers+inauthor:keyes&dq=flowers+inauthor:keyes&hl=&cd=7&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=LRlCAAAAYAAJ&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Some_Environmental_Factors_Influencing_B.html?hl=&id=LRlCAAAAYAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=LRlCAAAAYAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Quo relation concernino <b>flower</b> production was consistantly observed, and too <br>\nwas one correlation botvos., abscission aiki flows: production. ...eliever <b>flower</b> <br>\nproduction was increasod too amount of bid abscission that took placs was fixed <br>\nas&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': 'uCqioAEACAAJ',
#    'etag': 'tDCUJjyf2yk',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/uCqioAEACAAJ',
#    'volumeInfo': {'title': 'Flowers for Algernon - Downloadable Multiple Critical Perspectives',
#     'authors': ['Daniel Keyes'],
#     'publishedDate': '2011-01-01',
#     'description': 'Probe the depth and richness of your favorite titles and usher your students into an understanding of what really made us want to teach literature in the first place. Each guide offers clear and concise explanations of three different critical perspectives.',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1935467972'},
#      {'type': 'ISBN_13', 'identifier': '9781935467977'}],
#     'readingModes': {'text': False, 'image': False},
#     'printType': 'BOOK',
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=uCqioAEACAAJ&dq=flowers+inauthor:keyes&hl=&cd=8&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=uCqioAEACAAJ&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Flowers_for_Algernon_Downloadable_Multip.html?hl=&id=uCqioAEACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=uCqioAEACAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Probe the depth and richness of your favorite titles and usher your students into an understanding of what really made us want to teach literature in the first place.'}},
#   {'kind': 'books#volume',
#    'id': 'vcZJAAAAIAAJ',
#    'etag': 'dD/pRMWOB3E',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/vcZJAAAAIAAJ',
#    'volumeInfo': {'title': 'Stories and Story-telling',
#     'authors': ['Angela Mary Keyes'],
#     'publishedDate': '1911',
#     'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'UCAL:$B262932'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 286,
#     'printType': 'BOOK',
#     'categories': ['Storytelling'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.2.3.0.full.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=vcZJAAAAIAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=vcZJAAAAIAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=vcZJAAAAIAAJ&pg=PA100&dq=flowers+inauthor:keyes&hl=&cd=9&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=vcZJAAAAIAAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=vcZJAAAAIAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FREE',
#     'isEbook': True,
#     'buyLink': 'https://play.google.com/store/books/details?id=vcZJAAAAIAAJ&rdid=book-vcZJAAAAIAAJ&rdot=1&source=gbs_api'},
#    'accessInfo': {'country': 'US',
#     'viewability': 'ALL_PAGES',
#     'embeddable': True,
#     'publicDomain': True,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False,
#      'downloadLink': 'http://books.google.com/books/download/Stories_and_Story_telling.epub?id=vcZJAAAAIAAJ&hl=&output=epub&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'downloadLink': 'http://books.google.com/books/download/Stories_and_Story_telling.pdf?id=vcZJAAAAIAAJ&hl=&output=pdf&sig=ACfU3U1ZlWJVN9HuKOKVjHyRzblks4jwng&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=vcZJAAAAIAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'FULL_PUBLIC_DOMAIN',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Pick out one of the splendid <b>flowers</b> you see down there, and I will set you down <br>\nin it.” “That will be a beautiful home,” cried Thumbelina, and clapped her hands. <br>\nShe chose a great white <b>flower</b>. The swallow flew down with her and set her on&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': '6WrhAAAAMAAJ',
#    'etag': 'aUqYL+tt4G0',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/6WrhAAAAMAAJ',
#    'volumeInfo': {'title': 'Algernon, Charlie, and I',
#     'subtitle': 'A Writer\'s Journey : Plus the Complete Original Short Novelette Version of "Flowers for Algernon"',
#     'authors': ['Daniel Keyes'],
#     'publisher': 'Challenge PressInc',
#     'publishedDate': '1999',
#     'description': 'The author shares his creative processes, revealing the life experiences leading to the creation of Charlie Gordon and tracing the evolution of the novelette into a novel, stage production, cinema production, and TV movie.',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'UOM:39015049675906'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 223,
#     'printType': 'BOOK',
#     'categories': ['Biography & Autobiography'],
#     'averageRating': 4,
#     'ratingsCount': 1,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=6WrhAAAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=6WrhAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=6WrhAAAAMAAJ&q=flowers+inauthor:keyes&dq=flowers+inauthor:keyes&hl=&cd=10&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=6WrhAAAAMAAJ&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Algernon_Charlie_and_I.html?hl=&id=6WrhAAAAMAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=6WrhAAAAMAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'The author shares his creative processes, revealing the life experiences leading to the creation of Charlie Gordon and tracing the evolution of the novelette into a novel, stage production, cinema production, and TV movie.'}}]}

# %%
with open('example_google_books_return.obj','ab') as f:
    pickle.dump(a,f)

# %%
with open('example_google_books_return.obj','rb') as f:
    b = pickle.load(f)

# %%
b
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 113,
#  'items': [{'kind': 'books#volume',
#    'id': 'gK98gXR8onwC',
#    'etag': 'ym8oWidtoE0',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/gK98gXR8onwC',
#    'volumeInfo': {'title': 'Flowers for Algernon',
#     'subtitle': 'A One-act Play',
#     'authors': ['David Rogers', 'Daniel Keyes'],
#     'publisher': 'Dramatic Publishing',
#     'publishedDate': '1969',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0871293870'},
#      {'type': 'ISBN_13', 'identifier': '9780871293879'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 32,
#     'printType': 'BOOK',
#     'averageRating': 5,
#     'ratingsCount': 1,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.0.2.0.preview.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=gK98gXR8onwC&pg=PA3&dq=flowers+inauthor:keyes&hl=&cd=1&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=gK98gXR8onwC&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Flowers_for_Algernon.html?hl=&id=gK98gXR8onwC'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=gK98gXR8onwC&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': '<b>FLOWERS</b> FOR ALGERNON A One-act Play For Four Men And One Woman” <br>\nCHARACTERS DR. STRAUSS . . . . . . . . . . . . . . . . . . . a young neurosurgeon <br>\nPROFESSOR NEMUR . . . . . . . . . . . . . . . . his older colleague ALICE KINNIAN&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': '_oG_iTxP1pIC',
#    'etag': 'Jes7pJi/E4Y',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/_oG_iTxP1pIC',
#    'volumeInfo': {'title': 'Flowers for Algernon',
#     'authors': ['Daniel Keyes'],
#     'publisher': 'Houghton Mifflin Harcourt',
#     'publishedDate': '2007-12-01',
#     'description': 'Oscar-winning film Charly starring Cliff Robertson and Claire Bloom-a mentally challenged man receives an operation that turns him into a genius...and introduces him to heartache.',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0547539630'},
#      {'type': 'ISBN_13', 'identifier': '9780547539638'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 304,
#     'printType': 'BOOK',
#     'categories': ['Fiction'],
#     'averageRating': 4,
#     'ratingsCount': 177,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': True,
#     'contentVersion': '1.12.11.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=_oG_iTxP1pIC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=_oG_iTxP1pIC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=_oG_iTxP1pIC&pg=PA225&dq=flowers+inauthor:keyes&hl=&cd=2&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=_oG_iTxP1pIC&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=_oG_iTxP1pIC'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 8.99, 'currencyCode': 'USD'},
#     'retailPrice': {'amount': 8.99, 'currencyCode': 'USD'},
#     'buyLink': 'https://play.google.com/store/books/details?id=_oG_iTxP1pIC&rdid=book-_oG_iTxP1pIC&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 8990000, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 8990000, 'currencyCode': 'USD'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Flowers_for_Algernon-sample-epub.acsm?id=_oG_iTxP1pIC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Flowers_for_Algernon-sample-pdf.acsm?id=_oG_iTxP1pIC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=_oG_iTxP1pIC&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False}},
#   {'kind': 'books#volume',
#    'id': 'wAUiAAAAMAAJ',
#    'etag': 'CEuD+avG3Fk',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/wAUiAAAAMAAJ',
#    'volumeInfo': {'title': 'Evan Dale',
#     'authors': ['F. Keyes'],
#     'publishedDate': '1864',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'NYPL:33433074876743'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 387,
#     'printType': 'BOOK',
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.1.1.0.full.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=wAUiAAAAMAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=wAUiAAAAMAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=wAUiAAAAMAAJ&pg=PA137&dq=flowers+inauthor:keyes&hl=&cd=3&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=wAUiAAAAMAAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=wAUiAAAAMAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FREE',
#     'isEbook': True,
#     'buyLink': 'https://play.google.com/store/books/details?id=wAUiAAAAMAAJ&rdid=book-wAUiAAAAMAAJ&rdot=1&source=gbs_api'},
#    'accessInfo': {'country': 'US',
#     'viewability': 'ALL_PAGES',
#     'embeddable': True,
#     'publicDomain': True,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False,
#      'downloadLink': 'http://books.google.com/books/download/Evan_Dale.epub?id=wAUiAAAAMAAJ&hl=&output=epub&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'downloadLink': 'http://books.google.com/books/download/Evan_Dale.pdf?id=wAUiAAAAMAAJ&hl=&output=pdf&sig=ACfU3U2Xg5OeqGIO0AvQ0NH19Kz80v0uRw&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=wAUiAAAAMAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'FULL_PUBLIC_DOMAIN',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'crushed on the unfeeling <b>flowers</b> of the carpet, take it tip tenderly, and curse the <br>\nfoot that spoiled it. For the rest of the evening Carleton was on an extensive <br>\nsearch of discovery for the missing <b>flower</b>. In truth, he was in great danger of <br>\nbecoming&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': 'wYB5PwAACAAJ',
#    'etag': 'nzRNkRjuXvg',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/wYB5PwAACAAJ',
#    'volumeInfo': {'title': 'Bloemen Voor Algernon',
#     'authors': ['Daniel Keyes'],
#     'publisher': 'Bantam Books',
#     'publishedDate': '1984-05-01',
#     'description': 'With more than five million copies sold, "Flowers for Algernon" is the beloved, classic story of a mentally disabled man whose experimental quest for intelligence mirrors that of Algernon, an extraordinary lab mouse. High school and older.',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0553169041'},
#      {'type': 'ISBN_13', 'identifier': '9780553169041'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 72,
#     'printType': 'BOOK',
#     'averageRating': 4,
#     'ratingsCount': 157,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=wYB5PwAACAAJ&dq=flowers+inauthor:keyes&hl=&cd=4&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=wYB5PwAACAAJ&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Bloemen_Voor_Algernon.html?hl=&id=wYB5PwAACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=wYB5PwAACAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'With more than five million copies sold, &quot;Flowers for Algernon&quot; is the beloved, classic story of a mentally disabled man whose experimental quest for intelligence mirrors that of Algernon, an extraordinary lab mouse. High school and older.'}},
#   {'kind': 'books#volume',
#    'id': 'jQxIAQAAMAAJ',
#    'etag': 'v3u/r482Yx0',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/jQxIAQAAMAAJ',
#    'volumeInfo': {'title': 'The Five Senses',
#     'authors': ['Angela Mary Keyes'],
#     'publishedDate': '1911',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'IOWA:31858006011708'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 252,
#     'printType': 'BOOK',
#     'categories': ['Senses and sensation'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'full-1.0.0',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=jQxIAQAAMAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=jQxIAQAAMAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=jQxIAQAAMAAJ&pg=PA203&dq=flowers+inauthor:keyes&hl=&cd=5&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=jQxIAQAAMAAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=jQxIAQAAMAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FREE',
#     'isEbook': True,
#     'buyLink': 'https://play.google.com/store/books/details?id=jQxIAQAAMAAJ&rdid=book-jQxIAQAAMAAJ&rdot=1&source=gbs_api'},
#    'accessInfo': {'country': 'US',
#     'viewability': 'ALL_PAGES',
#     'embeddable': True,
#     'publicDomain': True,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=jQxIAQAAMAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'FULL_PUBLIC_DOMAIN',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'In field and garden the <b>flowers</b> no longer stood forth gaily in their brightest colors. <br>\nButtercups and daisies bent on their ... “And O, Nell,” cried Ned, “there are no air <br>\nships taking callers from <b>flower</b> to <b>flower</b>.” “No,” said Nell, “perhaps it is too wet&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': 'xYK5oAEACAAJ',
#    'etag': 'UPnY+0ord50',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/xYK5oAEACAAJ',
#    'volumeInfo': {'title': 'Flowers for Algernon - Multiple Critical Perspectives',
#     'authors': ['Daniel Keyes'],
#     'publishedDate': '2011-01-01',
#     'description': 'Probe the depth and richness of your favorite titles and usher your students into an understanding of what really made us want to teach literature in the first place. Each guide offers clear and concise explanations of three different critical perspectives.',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1935467964'},
#      {'type': 'ISBN_13', 'identifier': '9781935467960'}],
#     'readingModes': {'text': False, 'image': False},
#     'printType': 'BOOK',
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=xYK5oAEACAAJ&dq=flowers+inauthor:keyes&hl=&cd=6&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=xYK5oAEACAAJ&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Flowers_for_Algernon_Multiple_Critical_P.html?hl=&id=xYK5oAEACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=xYK5oAEACAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Probe the depth and richness of your favorite titles and usher your students into an understanding of what really made us want to teach literature in the first place.'}},
#   {'kind': 'books#volume',
#    'id': 'LRlCAAAAYAAJ',
#    'etag': 'kU1SLj+zx1Q',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/LRlCAAAAYAAJ',
#    'volumeInfo': {'title': 'Some Environmental Factors Influencing Bud Formation, Abscission and Flower Production of Gardenias',
#     'authors': ['Curtis Gilbert Keyes'],
#     'publishedDate': '1946',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'CORNELL:31924002987646'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 190,
#     'printType': 'BOOK',
#     'categories': ['Gardenia'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.1.1.0.preview.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=LRlCAAAAYAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=LRlCAAAAYAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=LRlCAAAAYAAJ&q=flowers+inauthor:keyes&dq=flowers+inauthor:keyes&hl=&cd=7&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=LRlCAAAAYAAJ&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Some_Environmental_Factors_Influencing_B.html?hl=&id=LRlCAAAAYAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=LRlCAAAAYAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Quo relation concernino <b>flower</b> production was consistantly observed, and too <br>\nwas one correlation botvos., abscission aiki flows: production. ...eliever <b>flower</b> <br>\nproduction was increasod too amount of bid abscission that took placs was fixed <br>\nas&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': 'uCqioAEACAAJ',
#    'etag': 'tDCUJjyf2yk',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/uCqioAEACAAJ',
#    'volumeInfo': {'title': 'Flowers for Algernon - Downloadable Multiple Critical Perspectives',
#     'authors': ['Daniel Keyes'],
#     'publishedDate': '2011-01-01',
#     'description': 'Probe the depth and richness of your favorite titles and usher your students into an understanding of what really made us want to teach literature in the first place. Each guide offers clear and concise explanations of three different critical perspectives.',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1935467972'},
#      {'type': 'ISBN_13', 'identifier': '9781935467977'}],
#     'readingModes': {'text': False, 'image': False},
#     'printType': 'BOOK',
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=uCqioAEACAAJ&dq=flowers+inauthor:keyes&hl=&cd=8&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=uCqioAEACAAJ&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Flowers_for_Algernon_Downloadable_Multip.html?hl=&id=uCqioAEACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=uCqioAEACAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Probe the depth and richness of your favorite titles and usher your students into an understanding of what really made us want to teach literature in the first place.'}},
#   {'kind': 'books#volume',
#    'id': 'vcZJAAAAIAAJ',
#    'etag': 'dD/pRMWOB3E',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/vcZJAAAAIAAJ',
#    'volumeInfo': {'title': 'Stories and Story-telling',
#     'authors': ['Angela Mary Keyes'],
#     'publishedDate': '1911',
#     'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'UCAL:$B262932'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 286,
#     'printType': 'BOOK',
#     'categories': ['Storytelling'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.2.3.0.full.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=vcZJAAAAIAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=vcZJAAAAIAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=vcZJAAAAIAAJ&pg=PA100&dq=flowers+inauthor:keyes&hl=&cd=9&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=vcZJAAAAIAAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=vcZJAAAAIAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FREE',
#     'isEbook': True,
#     'buyLink': 'https://play.google.com/store/books/details?id=vcZJAAAAIAAJ&rdid=book-vcZJAAAAIAAJ&rdot=1&source=gbs_api'},
#    'accessInfo': {'country': 'US',
#     'viewability': 'ALL_PAGES',
#     'embeddable': True,
#     'publicDomain': True,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False,
#      'downloadLink': 'http://books.google.com/books/download/Stories_and_Story_telling.epub?id=vcZJAAAAIAAJ&hl=&output=epub&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'downloadLink': 'http://books.google.com/books/download/Stories_and_Story_telling.pdf?id=vcZJAAAAIAAJ&hl=&output=pdf&sig=ACfU3U1ZlWJVN9HuKOKVjHyRzblks4jwng&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=vcZJAAAAIAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'FULL_PUBLIC_DOMAIN',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Pick out one of the splendid <b>flowers</b> you see down there, and I will set you down <br>\nin it.” “That will be a beautiful home,” cried Thumbelina, and clapped her hands. <br>\nShe chose a great white <b>flower</b>. The swallow flew down with her and set her on&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': '6WrhAAAAMAAJ',
#    'etag': 'aUqYL+tt4G0',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/6WrhAAAAMAAJ',
#    'volumeInfo': {'title': 'Algernon, Charlie, and I',
#     'subtitle': 'A Writer\'s Journey : Plus the Complete Original Short Novelette Version of "Flowers for Algernon"',
#     'authors': ['Daniel Keyes'],
#     'publisher': 'Challenge PressInc',
#     'publishedDate': '1999',
#     'description': 'The author shares his creative processes, revealing the life experiences leading to the creation of Charlie Gordon and tracing the evolution of the novelette into a novel, stage production, cinema production, and TV movie.',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'UOM:39015049675906'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 223,
#     'printType': 'BOOK',
#     'categories': ['Biography & Autobiography'],
#     'averageRating': 4,
#     'ratingsCount': 1,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=6WrhAAAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=6WrhAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=6WrhAAAAMAAJ&q=flowers+inauthor:keyes&dq=flowers+inauthor:keyes&hl=&cd=10&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=6WrhAAAAMAAJ&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Algernon_Charlie_and_I.html?hl=&id=6WrhAAAAMAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=6WrhAAAAMAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'The author shares his creative processes, revealing the life experiences leading to the creation of Charlie Gordon and tracing the evolution of the novelette into a novel, stage production, cinema production, and TV movie.'}}]}

# %%
len(a['items'])
# Out:
# 10

# %%
relevant_details=['id','title','authors','publisher',
                  'publishedDate','description','industryIdentifiers',
                  'pageCount','categories','thumbnail','smallThumbnail',
                  'language','webReaderLink','textSnippet','isEbook']
a['items'][0].keys()
# Out:
# dict_keys(['kind', 'id', 'etag', 'selfLink', 'volumeInfo', 'saleInfo', 'accessInfo', 'searchInfo'])

# %%
type(a['items'][0]['volumeInfo'])
# Out:
# dict

# %%
new_dict
# Out:
# {'title': 'Flowers for Algernon',
#  'authors': ['David Rogers', 'Daniel Keyes'],
#  'publisher': 'Dramatic Publishing',
#  'pageCount': 32,
#  'language': 'en'}

# %%
def retreive_details(json_dict,relevant_values):
    new_dict={}
    i = 1
    for item in json_dict.keys():
        print("on item" + str(i) + ":"+item)
        if type(json_dict[item]) is dict:
            print("recursing")
            temp_dict = retreive_details(json_dict[item],relevant_values)
            print(temp_dict)
            new_dict.update(temp_dict)
        if item in relevant_details:
            new_dict[item] = json_dict[item] 
        i+=1
    return new_dict

# %%
if type(a['items'][0]['volumeInfo']) is dict:
    print("true")
# Out:
# true

# %%
a['items'][0]
# Out:
# {'kind': 'books#volume',
#  'id': 'gK98gXR8onwC',
#  'etag': 'ym8oWidtoE0',
#  'selfLink': 'https://www.googleapis.com/books/v1/volumes/gK98gXR8onwC',
#  'volumeInfo': {'title': 'Flowers for Algernon',
#   'subtitle': 'A One-act Play',
#   'authors': ['David Rogers', 'Daniel Keyes'],
#   'publisher': 'Dramatic Publishing',
#   'publishedDate': '1969',
#   'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0871293870'},
#    {'type': 'ISBN_13', 'identifier': '9780871293879'}],
#   'readingModes': {'text': False, 'image': True},
#   'pageCount': 32,
#   'printType': 'BOOK',
#   'averageRating': 5,
#   'ratingsCount': 1,
#   'maturityRating': 'NOT_MATURE',
#   'allowAnonLogging': False,
#   'contentVersion': '0.0.2.0.preview.1',
#   'panelizationSummary': {'containsEpubBubbles': False,
#    'containsImageBubbles': False},
#   'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#    'thumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#   'language': 'en',
#   'previewLink': 'http://books.google.com/books?id=gK98gXR8onwC&pg=PA3&dq=flowers+inauthor:keyes&hl=&cd=1&source=gbs_api',
#   'infoLink': 'http://books.google.com/books?id=gK98gXR8onwC&dq=flowers+inauthor:keyes&hl=&source=gbs_api',
#   'canonicalVolumeLink': 'https://books.google.com/books/about/Flowers_for_Algernon.html?hl=&id=gK98gXR8onwC'},
#  'saleInfo': {'country': 'US',
#   'saleability': 'NOT_FOR_SALE',
#   'isEbook': False},
#  'accessInfo': {'country': 'US',
#   'viewability': 'PARTIAL',
#   'embeddable': True,
#   'publicDomain': False,
#   'textToSpeechPermission': 'ALLOWED',
#   'epub': {'isAvailable': False},
#   'pdf': {'isAvailable': False},
#   'webReaderLink': 'http://play.google.com/books/reader?id=gK98gXR8onwC&hl=&printsec=frontcover&source=gbs_api',
#   'accessViewStatus': 'SAMPLE',
#   'quoteSharingAllowed': False},
#  'searchInfo': {'textSnippet': '<b>FLOWERS</b> FOR ALGERNON A One-act Play For Four Men And One Woman” <br>\nCHARACTERS DR. STRAUSS . . . . . . . . . . . . . . . . . . . a young neurosurgeon <br>\nPROFESSOR NEMUR . . . . . . . . . . . . . . . . his older colleague ALICE KINNIAN&nbsp;...'}}

# %%
retreive_details(a['items'][0],relevant_details)
# Out:
# on item1:kind
# on item2:id
# on item3:etag
# on item4:selfLink
# on item5:volumeInfo
# recursing
# on item1:title
# on item2:subtitle
# on item3:authors
# on item4:publisher
# on item5:publishedDate
# on item6:industryIdentifiers
# on item7:readingModes
# recursing
# on item1:text
# on item2:image
# {}
# on item8:pageCount
# on item9:printType
# on item10:averageRating
# on item11:ratingsCount
# on item12:maturityRating
# on item13:allowAnonLogging
# on item14:contentVersion
# on item15:panelizationSummary
# recursing
# on item1:containsEpubBubbles
# on item2:containsImageBubbles
# {}
# on item16:imageLinks
# recursing
# on item1:smallThumbnail
# on item2:thumbnail
# {'smallThumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api'}
# on item17:language
# on item18:previewLink
# on item19:infoLink
# on item20:canonicalVolumeLink
# {'title': 'Flowers for Algernon', 'authors': ['David Rogers', 'Daniel Keyes'], 'publisher': 'Dramatic Publishing', 'pageCount': 32, 'smallThumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'language': 'en'}
# on item6:saleInfo
# recursing
# on item1:country
# on item2:saleability
# on item3:isEbook
# {'isEbook': False}
# on item7:accessInfo
# recursing
# on item1:country
# on item2:viewability
# on item3:embeddable
# on item4:publicDomain
# on item5:textToSpeechPermission
# on item6:epub
# recursing
# on item1:isAvailable
# {}
# on item7:pdf
# recursing
# on item1:isAvailable
# {}
# on item8:webReaderLink
# on item9:accessViewStatus
# on item10:quoteSharingAllowed
# {}
# on item8:searchInfo
# recursing
# on item1:textSnippet
# {}
# {'id': 'gK98gXR8onwC',
#  'title': 'Flowers for Algernon',
#  'authors': ['David Rogers', 'Daniel Keyes'],
#  'publisher': 'Dramatic Publishing',
#  'pageCount': 32,
#  'smallThumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#  'language': 'en',
#  'isEbook': False}

# %%
my_dict_list = []
for item in a['items']:
    temp_dict = retreive_details(item,relevant_details)
    my_dict_list.append(temp_dict)
# Out:
# on item1:kind
# on item2:id
# on item3:etag
# on item4:selfLink
# on item5:volumeInfo
# recursing
# on item1:title
# on item2:subtitle
# on item3:authors
# on item4:publisher
# on item5:publishedDate
# on item6:industryIdentifiers
# on item7:readingModes
# recursing
# on item1:text
# on item2:image
# {}
# on item8:pageCount
# on item9:printType
# on item10:averageRating
# on item11:ratingsCount
# on item12:maturityRating
# on item13:allowAnonLogging
# on item14:contentVersion
# on item15:panelizationSummary
# recursing
# on item1:containsEpubBubbles
# on item2:containsImageBubbles
# {}
# on item16:imageLinks
# recursing
# on item1:smallThumbnail
# on item2:thumbnail
# {'smallThumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}
# on item17:language
# on item18:previewLink
# on item19:infoLink
# on item20:canonicalVolumeLink
# {'title': 'Flowers for Algernon', 'authors': ['David Rogers', 'Daniel Keyes'], 'publisher': 'Dramatic Publishing', 'publishedDate': '1969', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0871293870'}, {'type': 'ISBN_13', 'identifier': '9780871293879'}], 'pageCount': 32, 'smallThumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'language': 'en'}
# on item6:saleInfo
# recursing
# on item1:country
# on item2:saleability
# on item3:isEbook
# {'isEbook': False}
# on item7:accessInfo
# recursing
# on item1:country
# on item2:viewability
# on item3:embeddable
# on item4:publicDomain
# on item5:textToSpeechPermission
# on item6:epub
# recursing
# on item1:isAvailable
# {}
# on item7:pdf
# recursing
# on item1:isAvailable
# {}
# on item8:webReaderLink
# on item9:accessViewStatus
# on item10:quoteSharingAllowed
# {}
# on item8:searchInfo
# recursing
# on item1:textSnippet
# {}
# on item1:kind
# on item2:id
# on item3:etag
# on item4:selfLink
# on item5:volumeInfo
# recursing
# on item1:title
# on item2:authors
# on item3:publisher
# on item4:publishedDate
# on item5:description
# on item6:industryIdentifiers
# on item7:readingModes
# recursing
# on item1:text
# on item2:image
# {}
# on item8:pageCount
# on item9:printType
# on item10:categories
# on item11:averageRating
# on item12:ratingsCount
# on item13:maturityRating
# on item14:allowAnonLogging
# on item15:contentVersion
# on item16:panelizationSummary
# recursing
# on item1:containsEpubBubbles
# on item2:containsImageBubbles
# {}
# on item17:imageLinks
# recursing
# on item1:smallThumbnail
# on item2:thumbnail
# {'smallThumbnail': 'http://books.google.com/books/content?id=_oG_iTxP1pIC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=_oG_iTxP1pIC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}
# on item18:language
# on item19:previewLink
# on item20:infoLink
# on item21:canonicalVolumeLink
# {'title': 'Flowers for Algernon', 'authors': ['Daniel Keyes'], 'publisher': 'Houghton Mifflin Harcourt', 'publishedDate': '2007-12-01', 'description': 'Oscar-winning film Charly starring Cliff Robertson and Claire Bloom-a mentally challenged man receives an operation that turns him into a genius...and introduces him to heartache.', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0547539630'}, {'type': 'ISBN_13', 'identifier': '9780547539638'}], 'pageCount': 304, 'categories': ['Fiction'], 'smallThumbnail': 'http://books.google.com/books/content?id=_oG_iTxP1pIC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=_oG_iTxP1pIC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'language': 'en'}
# on item6:saleInfo
# recursing
# on item1:country
# on item2:saleability
# on item3:isEbook
# on item4:listPrice
# recursing
# on item1:amount
# on item2:currencyCode
# {}
# on item5:retailPrice
# recursing
# on item1:amount
# on item2:currencyCode
# {}
# on item6:buyLink
# on item7:offers
# {'isEbook': True}
# on item7:accessInfo
# recursing
# on item1:country
# on item2:viewability
# on item3:embeddable
# on item4:publicDomain
# on item5:textToSpeechPermission
# on item6:epub
# recursing
# on item1:isAvailable
# on item2:acsTokenLink
# {}
# on item7:pdf
# recursing
# on item1:isAvailable
# on item2:acsTokenLink
# {}
# on item8:webReaderLink
# on item9:accessViewStatus
# on item10:quoteSharingAllowed
# {}
# on item1:kind
# on item2:id
# on item3:etag
# on item4:selfLink
# on item5:volumeInfo
# recursing
# on item1:title
# on item2:authors
# on item3:publishedDate
# on item4:industryIdentifiers
# on item5:readingModes
# recursing
# on item1:text
# on item2:image
# {}
# on item6:pageCount
# on item7:printType
# on item8:maturityRating
# on item9:allowAnonLogging
# on item10:contentVersion
# on item11:panelizationSummary
# recursing
# on item1:containsEpubBubbles
# on item2:containsImageBubbles
# {}
# on item12:imageLinks
# recursing
# on item1:smallThumbnail
# on item2:thumbnail
# {'smallThumbnail': 'http://books.google.com/books/content?id=wAUiAAAAMAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=wAUiAAAAMAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}
# on item13:language
# on item14:previewLink
# on item15:infoLink
# on item16:canonicalVolumeLink
# {'title': 'Evan Dale', 'authors': ['F. Keyes'], 'publishedDate': '1864', 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'NYPL:33433074876743'}], 'pageCount': 387, 'smallThumbnail': 'http://books.google.com/books/content?id=wAUiAAAAMAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=wAUiAAAAMAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'language': 'en'}
# on item6:saleInfo
# recursing
# on item1:country
# on item2:saleability
# on item3:isEbook
# on item4:buyLink
# {'isEbook': True}
# on item7:accessInfo
# recursing
# on item1:country
# on item2:viewability
# on item3:embeddable
# on item4:publicDomain
# on item5:textToSpeechPermission
# on item6:epub
# recursing
# on item1:isAvailable
# on item2:downloadLink
# {}
# on item7:pdf
# recursing
# on item1:isAvailable
# on item2:downloadLink
# {}
# on item8:webReaderLink
# on item9:accessViewStatus
# on item10:quoteSharingAllowed
# {}
# on item8:searchInfo
# recursing
# on item1:textSnippet
# {}
# on item1:kind
# on item2:id
# on item3:etag
# on item4:selfLink
# on item5:volumeInfo
# recursing
# on item1:title
# on item2:authors
# on item3:publisher
# on item4:publishedDate
# on item5:description
# on item6:industryIdentifiers
# on item7:readingModes
# recursing
# on item1:text
# on item2:image
# {}
# on item8:pageCount
# on item9:printType
# on item10:averageRating
# on item11:ratingsCount
# on item12:maturityRating
# on item13:allowAnonLogging
# on item14:contentVersion
# on item15:language
# on item16:previewLink
# on item17:infoLink
# on item18:canonicalVolumeLink
# {'title': 'Bloemen Voor Algernon', 'authors': ['Daniel Keyes'], 'publisher': 'Bantam Books', 'publishedDate': '1984-05-01', 'description': 'With more than five million copies sold, "Flowers for Algernon" is the beloved, classic story of a mentally disabled man whose experimental quest for intelligence mirrors that of Algernon, an extraordinary lab mouse. High school and older.', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0553169041'}, {'type': 'ISBN_13', 'identifier': '9780553169041'}], 'pageCount': 72, 'language': 'en'}
# on item6:saleInfo
# recursing
# on item1:country
# on item2:saleability
# on item3:isEbook
# {'isEbook': False}
# on item7:accessInfo
# recursing
# on item1:country
# on item2:viewability
# on item3:embeddable
# on item4:publicDomain
# on item5:textToSpeechPermission
# on item6:epub
# recursing
# on item1:isAvailable
# {}
# on item7:pdf
# recursing
# on item1:isAvailable
# {}
# on item8:webReaderLink
# on item9:accessViewStatus
# on item10:quoteSharingAllowed
# {}
# on item8:searchInfo
# recursing
# on item1:textSnippet
# {}
# on item1:kind
# on item2:id
# on item3:etag
# on item4:selfLink
# on item5:volumeInfo
# recursing
# on item1:title
# on item2:authors
# on item3:publishedDate
# on item4:industryIdentifiers
# on item5:readingModes
# recursing
# on item1:text
# on item2:image
# {}
# on item6:pageCount
# on item7:printType
# on item8:categories
# on item9:maturityRating
# on item10:allowAnonLogging
# on item11:contentVersion
# on item12:imageLinks
# recursing
# on item1:smallThumbnail
# on item2:thumbnail
# {'smallThumbnail': 'http://books.google.com/books/content?id=jQxIAQAAMAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=jQxIAQAAMAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}
# on item13:language
# on item14:previewLink
# on item15:infoLink
# on item16:canonicalVolumeLink
# {'title': 'The Five Senses', 'authors': ['Angela Mary Keyes'], 'publishedDate': '1911', 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'IOWA:31858006011708'}], 'pageCount': 252, 'categories': ['Senses and sensation'], 'smallThumbnail': 'http://books.google.com/books/content?id=jQxIAQAAMAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=jQxIAQAAMAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'language': 'en'}
# on item6:saleInfo
# recursing
# on item1:country
# on item2:saleability
# on item3:isEbook
# on item4:buyLink
# {'isEbook': True}
# on item7:accessInfo
# recursing
# on item1:country
# on item2:viewability
# on item3:embeddable
# on item4:publicDomain
# on item5:textToSpeechPermission
# on item6:epub
# recursing
# on item1:isAvailable
# {}
# on item7:pdf
# recursing
# on item1:isAvailable
# {}
# on item8:webReaderLink
# on item9:accessViewStatus
# on item10:quoteSharingAllowed
# {}
# on item8:searchInfo
# recursing
# on item1:textSnippet
# {}
# on item1:kind
# on item2:id
# on item3:etag
# on item4:selfLink
# on item5:volumeInfo
# recursing
# on item1:title
# on item2:authors
# on item3:publishedDate
# on item4:description
# on item5:industryIdentifiers
# on item6:readingModes
# recursing
# on item1:text
# on item2:image
# {}
# on item7:printType
# on item8:maturityRating
# on item9:allowAnonLogging
# on item10:contentVersion
# on item11:language
# on item12:previewLink
# on item13:infoLink
# on item14:canonicalVolumeLink
# {'title': 'Flowers for Algernon - Multiple Critical Perspectives', 'authors': ['Daniel Keyes'], 'publishedDate': '2011-01-01', 'description': 'Probe the depth and richness of your favorite titles and usher your students into an understanding of what really made us want to teach literature in the first place. Each guide offers clear and concise explanations of three different critical perspectives.', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1935467964'}, {'type': 'ISBN_13', 'identifier': '9781935467960'}], 'language': 'en'}
# on item6:saleInfo
# recursing
# on item1:country
# on item2:saleability
# on item3:isEbook
# {'isEbook': False}
# on item7:accessInfo
# recursing
# on item1:country
# on item2:viewability
# on item3:embeddable
# on item4:publicDomain
# on item5:textToSpeechPermission
# on item6:epub
# recursing
# on item1:isAvailable
# {}
# on item7:pdf
# recursing
# on item1:isAvailable
# {}
# on item8:webReaderLink
# on item9:accessViewStatus
# on item10:quoteSharingAllowed
# {}
# on item8:searchInfo
# recursing
# on item1:textSnippet
# {}
# on item1:kind
# on item2:id
# on item3:etag
# on item4:selfLink
# on item5:volumeInfo
# recursing
# on item1:title
# on item2:authors
# on item3:publishedDate
# on item4:industryIdentifiers
# on item5:readingModes
# recursing
# on item1:text
# on item2:image
# {}
# on item6:pageCount
# on item7:printType
# on item8:categories
# on item9:maturityRating
# on item10:allowAnonLogging
# on item11:contentVersion
# on item12:panelizationSummary
# recursing
# on item1:containsEpubBubbles
# on item2:containsImageBubbles
# {}
# on item13:imageLinks
# recursing
# on item1:smallThumbnail
# on item2:thumbnail
# {'smallThumbnail': 'http://books.google.com/books/content?id=LRlCAAAAYAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=LRlCAAAAYAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}
# on item14:language
# on item15:previewLink
# on item16:infoLink
# on item17:canonicalVolumeLink
# {'title': 'Some Environmental Factors Influencing Bud Formation, Abscission and Flower Production of Gardenias', 'authors': ['Curtis Gilbert Keyes'], 'publishedDate': '1946', 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'CORNELL:31924002987646'}], 'pageCount': 190, 'categories': ['Gardenia'], 'smallThumbnail': 'http://books.google.com/books/content?id=LRlCAAAAYAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=LRlCAAAAYAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'language': 'en'}
# on item6:saleInfo
# recursing
# on item1:country
# on item2:saleability
# on item3:isEbook
# {'isEbook': False}
# on item7:accessInfo
# recursing
# on item1:country
# on item2:viewability
# on item3:embeddable
# on item4:publicDomain
# on item5:textToSpeechPermission
# on item6:epub
# recursing
# on item1:isAvailable
# {}
# on item7:pdf
# recursing
# on item1:isAvailable
# {}
# on item8:webReaderLink
# on item9:accessViewStatus
# on item10:quoteSharingAllowed
# {}
# on item8:searchInfo
# recursing
# on item1:textSnippet
# {}
# on item1:kind
# on item2:id
# on item3:etag
# on item4:selfLink
# on item5:volumeInfo
# recursing
# on item1:title
# on item2:authors
# on item3:publishedDate
# on item4:description
# on item5:industryIdentifiers
# on item6:readingModes
# recursing
# on item1:text
# on item2:image
# {}
# on item7:printType
# on item8:maturityRating
# on item9:allowAnonLogging
# on item10:contentVersion
# on item11:language
# on item12:previewLink
# on item13:infoLink
# on item14:canonicalVolumeLink
# {'title': 'Flowers for Algernon - Downloadable Multiple Critical Perspectives', 'authors': ['Daniel Keyes'], 'publishedDate': '2011-01-01', 'description': 'Probe the depth and richness of your favorite titles and usher your students into an understanding of what really made us want to teach literature in the first place. Each guide offers clear and concise explanations of three different critical perspectives.', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1935467972'}, {'type': 'ISBN_13', 'identifier': '9781935467977'}], 'language': 'en'}
# on item6:saleInfo
# recursing
# on item1:country
# on item2:saleability
# on item3:isEbook
# {'isEbook': False}
# on item7:accessInfo
# recursing
# on item1:country
# on item2:viewability
# on item3:embeddable
# on item4:publicDomain
# on item5:textToSpeechPermission
# on item6:epub
# recursing
# on item1:isAvailable
# {}
# on item7:pdf
# recursing
# on item1:isAvailable
# {}
# on item8:webReaderLink
# on item9:accessViewStatus
# on item10:quoteSharingAllowed
# {}
# on item8:searchInfo
# recursing
# on item1:textSnippet
# {}
# on item1:kind
# on item2:id
# on item3:etag
# on item4:selfLink
# on item5:volumeInfo
# recursing
# on item1:title
# on item2:authors
# on item3:publishedDate
# on item4:industryIdentifiers
# on item5:readingModes
# recursing
# on item1:text
# on item2:image
# {}
# on item6:pageCount
# on item7:printType
# on item8:categories
# on item9:maturityRating
# on item10:allowAnonLogging
# on item11:contentVersion
# on item12:panelizationSummary
# recursing
# on item1:containsEpubBubbles
# on item2:containsImageBubbles
# {}
# on item13:imageLinks
# recursing
# on item1:smallThumbnail
# on item2:thumbnail
# {'smallThumbnail': 'http://books.google.com/books/content?id=vcZJAAAAIAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=vcZJAAAAIAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}
# on item14:language
# on item15:previewLink
# on item16:infoLink
# on item17:canonicalVolumeLink
# {'title': 'Stories and Story-telling', 'authors': ['Angela Mary Keyes'], 'publishedDate': '1911', 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'UCAL:$B262932'}], 'pageCount': 286, 'categories': ['Storytelling'], 'smallThumbnail': 'http://books.google.com/books/content?id=vcZJAAAAIAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=vcZJAAAAIAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'language': 'en'}
# on item6:saleInfo
# recursing
# on item1:country
# on item2:saleability
# on item3:isEbook
# on item4:buyLink
# {'isEbook': True}
# on item7:accessInfo
# recursing
# on item1:country
# on item2:viewability
# on item3:embeddable
# on item4:publicDomain
# on item5:textToSpeechPermission
# on item6:epub
# recursing
# on item1:isAvailable
# on item2:downloadLink
# {}
# on item7:pdf
# recursing
# on item1:isAvailable
# on item2:downloadLink
# {}
# on item8:webReaderLink
# on item9:accessViewStatus
# on item10:quoteSharingAllowed
# {}
# on item8:searchInfo
# recursing
# on item1:textSnippet
# {}
# on item1:kind
# on item2:id
# on item3:etag
# on item4:selfLink
# on item5:volumeInfo
# recursing
# on item1:title
# on item2:subtitle
# on item3:authors
# on item4:publisher
# on item5:publishedDate
# on item6:description
# on item7:industryIdentifiers
# on item8:readingModes
# recursing
# on item1:text
# on item2:image
# {}
# on item9:pageCount
# on item10:printType
# on item11:categories
# on item12:averageRating
# on item13:ratingsCount
# on item14:maturityRating
# on item15:allowAnonLogging
# on item16:contentVersion
# on item17:imageLinks
# recursing
# on item1:smallThumbnail
# on item2:thumbnail
# {'smallThumbnail': 'http://books.google.com/books/content?id=6WrhAAAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=6WrhAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}
# on item18:language
# on item19:previewLink
# on item20:infoLink
# on item21:canonicalVolumeLink
# {'title': 'Algernon, Charlie, and I', 'authors': ['Daniel Keyes'], 'publisher': 'Challenge PressInc', 'publishedDate': '1999', 'description': 'The author shares his creative processes, revealing the life experiences leading to the creation of Charlie Gordon and tracing the evolution of the novelette into a novel, stage production, cinema production, and TV movie.', 'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'UOM:39015049675906'}], 'pageCount': 223, 'categories': ['Biography & Autobiography'], 'smallThumbnail': 'http://books.google.com/books/content?id=6WrhAAAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=6WrhAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'language': 'en'}
# on item6:saleInfo
# recursing
# on item1:country
# on item2:saleability
# on item3:isEbook
# {'isEbook': False}
# on item7:accessInfo
# recursing
# on item1:country
# on item2:viewability
# on item3:embeddable
# on item4:publicDomain
# on item5:textToSpeechPermission
# on item6:epub
# recursing
# on item1:isAvailable
# {}
# on item7:pdf
# recursing
# on item1:isAvailable
# {}
# on item8:webReaderLink
# on item9:accessViewStatus
# on item10:quoteSharingAllowed
# {}
# on item8:searchInfo
# recursing
# on item1:textSnippet
# {}

# %%
my_dict_list
# Out:
# [{'id': 'gK98gXR8onwC',
#   'title': 'Flowers for Algernon',
#   'authors': ['David Rogers', 'Daniel Keyes'],
#   'publisher': 'Dramatic Publishing',
#   'publishedDate': '1969',
#   'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0871293870'},
#    {'type': 'ISBN_13', 'identifier': '9780871293879'}],
#   'pageCount': 32,
#   'smallThumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#   'thumbnail': 'http://books.google.com/books/content?id=gK98gXR8onwC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api',
#   'language': 'en',
#   'isEbook': False},
#  {'id': '_oG_iTxP1pIC',
#   'title': 'Flowers for Algernon',
#   'authors': ['Daniel Keyes'],
#   'publisher': 'Houghton Mifflin Harcourt',
#   'publishedDate': '2007-12-01',
#   'description': 'Oscar-winning film Charly starring Cliff Robertson and Claire Bloom-a mentally challenged man receives an operation that turns him into a genius...and introduces him to heartache.',
#   'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0547539630'},
#    {'type': 'ISBN_13', 'identifier': '9780547539638'}],
#   'pageCount': 304,
#   'categories': ['Fiction'],
#   'smallThumbnail': 'http://books.google.com/books/content?id=_oG_iTxP1pIC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#   'thumbnail': 'http://books.google.com/books/content?id=_oG_iTxP1pIC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api',
#   'language': 'en',
#   'isEbook': True},
#  {'id': 'wAUiAAAAMAAJ',
#   'title': 'Evan Dale',
#   'authors': ['F. Keyes'],
#   'publishedDate': '1864',
#   'industryIdentifiers': [{'type': 'OTHER',
#     'identifier': 'NYPL:33433074876743'}],
#   'pageCount': 387,
#   'smallThumbnail': 'http://books.google.com/books/content?id=wAUiAAAAMAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#   'thumbnail': 'http://books.google.com/books/content?id=wAUiAAAAMAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api',
#   'language': 'en',
#   'isEbook': True},
#  {'id': 'wYB5PwAACAAJ',
#   'title': 'Bloemen Voor Algernon',
#   'authors': ['Daniel Keyes'],
#   'publisher': 'Bantam Books',
#   'publishedDate': '1984-05-01',
#   'description': 'With more than five million copies sold, "Flowers for Algernon" is the beloved, classic story of a mentally disabled man whose experimental quest for intelligence mirrors that of Algernon, an extraordinary lab mouse. High school and older.',
#   'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0553169041'},
#    {'type': 'ISBN_13', 'identifier': '9780553169041'}],
#   'pageCount': 72,
#   'language': 'en',
#   'isEbook': False},
#  {'id': 'jQxIAQAAMAAJ',
#   'title': 'The Five Senses',
#   'authors': ['Angela Mary Keyes'],
#   'publishedDate': '1911',
#   'industryIdentifiers': [{'type': 'OTHER',
#     'identifier': 'IOWA:31858006011708'}],
#   'pageCount': 252,
#   'categories': ['Senses and sensation'],
#   'smallThumbnail': 'http://books.google.com/books/content?id=jQxIAQAAMAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#   'thumbnail': 'http://books.google.com/books/content?id=jQxIAQAAMAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api',
#   'language': 'en',
#   'isEbook': True},
#  {'id': 'xYK5oAEACAAJ',
#   'title': 'Flowers for Algernon - Multiple Critical Perspectives',
#   'authors': ['Daniel Keyes'],
#   'publishedDate': '2011-01-01',
#   'description': 'Probe the depth and richness of your favorite titles and usher your students into an understanding of what really made us want to teach literature in the first place. Each guide offers clear and concise explanations of three different critical perspectives.',
#   'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1935467964'},
#    {'type': 'ISBN_13', 'identifier': '9781935467960'}],
#   'language': 'en',
#   'isEbook': False},
#  {'id': 'LRlCAAAAYAAJ',
#   'title': 'Some Environmental Factors Influencing Bud Formation, Abscission and Flower Production of Gardenias',
#   'authors': ['Curtis Gilbert Keyes'],
#   'publishedDate': '1946',
#   'industryIdentifiers': [{'type': 'OTHER',
#     'identifier': 'CORNELL:31924002987646'}],
#   'pageCount': 190,
#   'categories': ['Gardenia'],
#   'smallThumbnail': 'http://books.google.com/books/content?id=LRlCAAAAYAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#   'thumbnail': 'http://books.google.com/books/content?id=LRlCAAAAYAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api',
#   'language': 'en',
#   'isEbook': False},
#  {'id': 'uCqioAEACAAJ',
#   'title': 'Flowers for Algernon - Downloadable Multiple Critical Perspectives',
#   'authors': ['Daniel Keyes'],
#   'publishedDate': '2011-01-01',
#   'description': 'Probe the depth and richness of your favorite titles and usher your students into an understanding of what really made us want to teach literature in the first place. Each guide offers clear and concise explanations of three different critical perspectives.',
#   'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1935467972'},
#    {'type': 'ISBN_13', 'identifier': '9781935467977'}],
#   'language': 'en',
#   'isEbook': False},
#  {'id': 'vcZJAAAAIAAJ',
#   'title': 'Stories and Story-telling',
#   'authors': ['Angela Mary Keyes'],
#   'publishedDate': '1911',
#   'industryIdentifiers': [{'type': 'OTHER', 'identifier': 'UCAL:$B262932'}],
#   'pageCount': 286,
#   'categories': ['Storytelling'],
#   'smallThumbnail': 'http://books.google.com/books/content?id=vcZJAAAAIAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#   'thumbnail': 'http://books.google.com/books/content?id=vcZJAAAAIAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api',
#   'language': 'en',
#   'isEbook': True},
#  {'id': '6WrhAAAAMAAJ',
#   'title': 'Algernon, Charlie, and I',
#   'authors': ['Daniel Keyes'],
#   'publisher': 'Challenge PressInc',
#   'publishedDate': '1999',
#   'description': 'The author shares his creative processes, revealing the life experiences leading to the creation of Charlie Gordon and tracing the evolution of the novelette into a novel, stage production, cinema production, and TV movie.',
#   'industryIdentifiers': [{'type': 'OTHER',
#     'identifier': 'UOM:39015049675906'}],
#   'pageCount': 223,
#   'categories': ['Biography & Autobiography'],
#   'smallThumbnail': 'http://books.google.com/books/content?id=6WrhAAAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#   'thumbnail': 'http://books.google.com/books/content?id=6WrhAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api',
#   'language': 'en',
#   'isEbook': False}]

# %% [markdown]
# Now things are in the right form I have to write 1 function to unpack the isbn values, and I need to change some of the names of extracted features to match the return format. I need to change the following from existing ids/ structure to the following structure
#
# id --> googleId: STRING
#
# industry identifiers -->
#
# isbn10: STRING
#
# isbn13: STRING
