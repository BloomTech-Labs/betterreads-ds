# %%
import psycopg2
engine = psycopg2.connect(
    database="betterreads",
    user="betterreadsadmin",
    password="betterreadsadmin",
    host="betterreads-datascience-database.cvmplnwee5ws.us-east-1.rds.amazonaws.com",
    port='5432')

# %%
import traceback
error_log = []
traces = []

def q(query, verbosity = False):
    data = 'No Data'
    curs = engine.cursor()
    try:
        curs.execute(query)
        if(verbosity):
            data = curs.fetchall()
    except psycopg2.errors.InvalidTextRepresentation as err:
        start = int(err.diag.statement_position)
        end = query.find('\'')
        replacement = '{'+query[start:end]+'}'
        new_query = query[:start] + replacement + query[start+len(replacement):]
        engine.rollback()
        q(new_query, verbosity)
        
    except Exception as e:
        engine.rollback()
        print(e)
        traceback.print_exc()
        error_log.append(e)

    engine.commit()
    curs.close()
    if(verbosity):
        return data

# %%
types_query = """
    select data_type 
    from information_schema.columns 
    where table_name = '{}';
    """
sql_to_py = {'text':str, 'ARRAY':list, 'integer':int}


#The data dict for each type holds the name given from the OpenLibrary data dump and the corresponding column name in the PostgreSQL database on AWS
edition_data_dict = {'title':'EditionTitle',
                    'authors':'Authors',
                    'genres':'Genre',
                    'subjects':'Subjects',
                    'publish_date':'PublishedYear',
                    'publishers':'Publisher',
                    'number_of_pages':'Pages',
                    'ratings':'Ratings',
                    'popularity':'Popularity',
                    'reviews':'Reviews',
                    'translated_from':'OriginalLanguage',
                    'location':'Nationality',
                    'translators':'Translators',
                    'work_titles':'WorkTitles',
                    'works':'Works',
                    'languages':'Languages',
                    'isbn_13':'ISBN13'}

editions_types = [sql_to_py[x[0]] for x in q(types_query.format('editions'), verbosity=True)]
editions_types_ol = {key:value for key,value in zip(list(edition_data_dict.keys()),editions_types)}
editions_types_db = {key:value for key,value in zip(list(edition_data_dict.values()),editions_types)}

# Author dict
author_data_dict = {'name':'Name',
                   'works':'Works',
                   'key':'Key'}

authors_types = [sql_to_py[x[0]] for x in q(types_query.format('authors'), verbosity=True)]
authors_types_ol = {key:value for key,value in zip(list(author_data_dict.keys()),authors_types)}
authors_types_db = {key:value for key,value in zip(list(author_data_dict.values()),authors_types)}

work_data_dict = {'title':'WorkTitle',
                 'authors':'Authors',
                 'subjects':'Subjects',
                 'description':'Description',
                 'first_publish_date':'FirstPublishDate',
                 'editions':'Editions',
                 'other_titles':'OtherTitles',
                 'translated_titles':'TranslatedTitles'}

works_types = [sql_to_py[x[0]] for x in q(types_query.format('works'), verbosity=True)]
works_types_ol = {key:value for key,value in zip(list(work_data_dict.keys()),works_types)}
works_types_db = {key:value for key,value in zip(list(work_data_dict.values()),works_types)}

# %%
#Helper method to generate dictionaries from their respective data_dict based on the type_line given
def generate_dictionaries(type_name):
    data_dict = globals()[('{}_data_dict'.format(type_name))]
    return {x: [] for x in data_dict.values()}

# %%
types_query = """
    select data_type 
    from information_schema.columns 
    where table_name = '{}';
    """

alpher = q(types_query.format('editions'), verbosity=True)
len(alpher)
# Out:
# 18

# %%
#Helper method to verify the input and make sure it is formatted correctly, then returns it as a dictionary
def verify_input(input_string, type_name):
    try:
        input_string = input_string.replace('null', '')
        input_string = input_string.replace('true', 'True')
        input_string = input_string.replace('false', 'False')
        if(type(input_string) != dict):
            input_string = eval(input_string)
        
        data_dict = globals()[('{}_data_dict'.format(type_name))]
        types_dict = globals()[('{}s_types_ol'.format(type_name))]
        
        for key in data_dict.keys():
            if key not in input_string.keys():
                missing_key_type = types_dict[key]
                input_string[key] = missing_key_type ()
        
        return input_string
    
    except Exception as e:
        exceptions.append(('verify_input',traceback.format_exc(),e,input_string))

# %%
#Helper method to add a data line to the correct dictionary
def add_to_dict(input_dictionary, type_name):
    target_dict = globals()[('{}s'.format(type_name))]
    data_dict = globals()[('{}_data_dict'.format(type_name))]
    
    for key in data_dict.keys():
        target_dict[data_dict[key]].append(input_dictionary[key])
    
    return True

# %%
#Acceptable type_names
type_names = ['author','edition','work']

#Master function that can be modified for ease of use
#Runs the two helper functions for processing data
def process_data(input_string, type_line):
    # Generates the type_name from the type_line's format
    type_name = type_line.split('/')[-1:][0]
    
    if(type_name not in type_names):
        return
    
    try:
        verified_dict = verify_input(input_string, type_name)
        add_to_dict(verified_dict, type_name)
    except Exception as e:
        exceptions.append(('process data',e, input_string))

# %%
def type_verify(input_key, input_data, type_dict):
    target_type = type_dict[input_key]
    
    if(target_type == str):
        s = str(input_data)
        s = s.replace('\'','').replace('\"','')
        if s == '':
            s = '-1'
        s = str(s)
        s = '\''+s+'\''
        return s
    
    if(target_type == int):
        return int(input_data)
    
    if(target_type == list):
        r = 'ARRAY [$$NULL$$]'
        data = [str(s).replace('\'','').replace('\"','') for s in input_data]
        if (len(data) != 0):
            r = 'ARRAY {}'.format(data)
        return r
    
    return 'Error'

# %%
def generate_lines(input_dict, types_dict):
    lines = {}
    
    for counter in range(0,len(input_dict[list(input_dict.keys())[0]])-1):
        line = []
        for key in input_dict.keys():
            processed_val = type_verify(key, input_dict[key][counter], types_dict)
            line.append(processed_val)
        lines[counter] = line   
    return lines

# %%
def generate_query(input_lines, table_name, columns):
    qBase = 'INSERT INTO "{}" ({}) VALUES '.format(table_name, columns)
    
    lines = []
    
    for line,counter in zip(input_lines, range(0,len(input_lines))):
        data = [str(x) for x in input_lines[line]]
        try:
            lines.append('('+','.join(data)+')')
        except Exception as e:
            exceptions.append((e,input_lines[line],counter))
    
    if(len(lines) == 0):
        return ''
    
    qBase = qBase + ','.join(lines) + ';'
    
    return qBase

# %%
def send_data(query):
    
    if(query != ''):
        q(query)
        return True
    else:
        print('\t\tNo data')
        return False

# %%
def to_database(input_dict, type_name):
    # Select the data dict
    data_dict = globals()[('{}_data_dict'.format(type_name))]
    # Select the types dictionary
    type_table = globals()[('{}s_types_db'.format(type_name))]
    # Set Table Name
    table_name = type_name+'s'
    # generate the columns on the database side with proper formatting
    columns = str(list(data_dict.values())).replace('[','').replace(']','').replace('\'', '\"')
    
    print('\tformatting lines')
    # generate the lines in a dictionary of strings where line 0 is at {0:line_data}
    formatted_lines = generate_lines(input_dict, type_table)
    
    print('\tgenerating query')
    # generate the final query from the formatted lines, table name, and columns string
    final_query = generate_query(formatted_lines, table_name, columns)
    
    print('\tquerying')
    # query the database adding the data 
    send_data(final_query)
    
    return True

# %%
import pickle

# %%
last_position = pickle.load(open('last_pos.pkl','rb'))

# %%
import time as t

exceptions = []
counter = 0

authors = generate_dictionaries('author')
editions = generate_dictionaries('edition')
works = generate_dictionaries('work')

with open(r'D:\New folder (3)\ol_dump_2020-01-31.txt\ol_dump_2020-01-31.txt', 'r', encoding='utf-8') as f:
    f.seek(last_position)
    while(True):
        line = f.readline()
        if(line == ''):
            break
        
        #Split the line by tabs to identifiy important chunks
        line = line.split('\t')
        
        #Run the process_data function
        process_data(line[4], line[0].strip())
        
        #Add to the batch counter
        counter += 1
        
        #Every 50,000 lines processed, send it to database
        if(counter%50000 == 0):
            last_position = f.tell()
            pickle.dump(last_position, open('last_pos.pkl','wb'))
            print('Exporting: #{}'.format(str(counter//50000)))
            start = t.time()
            print('\t#Sending Authors#')
            to_database(authors, 'author')
            print('\t#Sending Editions#')
            to_database(editions, 'edition')
            print('\t#Sending Works#')
            to_database(works, 'work')
            del(authors)
            del(editions)
            del(works)
            authors = generate_dictionaries('author')
            editions = generate_dictionaries('edition')
            works = generate_dictionaries('work')
            total =  t.time()-start
            print('\tExport time (s): {}'.format(total))
            print('\tCounter: {}'.format(counter))

# Final export of leftover data
to_database(authors, 'author')
to_database(editions, 'edition')
to_database(works, 'work')
# Out:
# Exporting: #1
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.599374294281006
# 	Counter: 50000
# Exporting: #2
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.261246681213379
# 	Counter: 100000
# Exporting: #3
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.73655390739441
# 	Counter: 150000
# Exporting: #4
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.699050664901733
# 	Counter: 200000
# Exporting: #5
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.267128944396973
# 	Counter: 250000
# Exporting: #6
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.083412647247314
# 	Counter: 300000
# Exporting: #7
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.556066751480103
# 	Counter: 350000
# Exporting: #8
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.1646904945373535
# 	Counter: 400000
# Exporting: #9
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.427770137786865
# 	Counter: 450000
# Exporting: #10
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.214419603347778
# 	Counter: 500000
# Exporting: #11
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.324180841445923
# 	Counter: 550000
# Exporting: #12
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.516195297241211
# 	Counter: 600000
# Exporting: #13
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.188849687576294
# 	Counter: 650000
# Exporting: #14
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 7.4684741497039795
# 	Counter: 700000
# Exporting: #15
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.253373622894287
# 	Counter: 750000
# Exporting: #16
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.2531578540802
# 	Counter: 800000
# Exporting: #17
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.859923601150513
# 	Counter: 850000
# Exporting: #18
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.081385850906372
# 	Counter: 900000
# Exporting: #19
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 12.001723051071167
# 	Counter: 950000
# Exporting: #20
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 10.137412548065186
# 	Counter: 1000000
# Exporting: #21
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.13082504272461
# 	Counter: 1050000
# Exporting: #22
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 3.9019062519073486
# 	Counter: 1100000
# Exporting: #23
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.39615797996521
# 	Counter: 1150000
# Exporting: #24
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.390877485275269
# 	Counter: 1200000
# Exporting: #25
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.459016561508179
# 	Counter: 1250000
# Exporting: #26
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.178544044494629
# 	Counter: 1300000
# Exporting: #27
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.266738891601562
# 	Counter: 1350000
# Exporting: #28
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.225979089736938
# 	Counter: 1400000
# Exporting: #29
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.543192386627197
# 	Counter: 1450000
# Exporting: #30
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.401271343231201
# 	Counter: 1500000
# Exporting: #31
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 6.271457672119141
# 	Counter: 1550000
# Exporting: #32
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.89355993270874
# 	Counter: 1600000
# Exporting: #33
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.509947538375854
# 	Counter: 1650000
# Exporting: #34
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.239850759506226
# 	Counter: 1700000
# Exporting: #35
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.884441614151001
# 	Counter: 1750000
# Exporting: #36
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.367164850234985
# 	Counter: 1800000
# Exporting: #37
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 'utf-8' codec can't encode characters in position 3147817-3147818: surrogates not allowed
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# Traceback (most recent call last):
#   File "<ipython-input-2-e92284ccb91b>", line 9, in q
#     curs.execute(query)
# UnicodeEncodeError: 'utf-8' codec can't encode characters in position 3147817-3147818: surrogates not allowed
# 	Export time (s): 2.7699973583221436
# 	Counter: 1850000
# Exporting: #38
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.7777276039123535
# 	Counter: 1900000
# Exporting: #39
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.2055816650390625
# 	Counter: 1950000
# Exporting: #40
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.812444686889648
# 	Counter: 2000000
# Exporting: #41
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.19689154624939
# 	Counter: 2050000
# Exporting: #42
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.941389322280884
# 	Counter: 2100000
# Exporting: #43
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.701470136642456
# 	Counter: 2150000
# Exporting: #44
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 8.32453179359436
# 	Counter: 2200000
# Exporting: #45
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.31512713432312
# 	Counter: 2250000
# Exporting: #46
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.875149965286255
# 	Counter: 2300000
# Exporting: #47
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.5902814865112305
# 	Counter: 2350000
# Exporting: #48
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 5.570540189743042
# 	Counter: 2400000
# Exporting: #49
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.026153802871704
# 	Counter: 2450000
# Exporting: #50
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.69369649887085
# 	Counter: 2500000
# Exporting: #51
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.96650767326355
# 	Counter: 2550000
# Exporting: #52
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.546365261077881
# 	Counter: 2600000
# Exporting: #53
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.08079481124878
# 	Counter: 2650000
# Exporting: #54
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 10.59996509552002
# 	Counter: 2700000
# Exporting: #55
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.668122291564941
# 	Counter: 2750000
# Exporting: #56
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.325246572494507
# 	Counter: 2800000
# Exporting: #57
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.529261589050293
# 	Counter: 2850000
# Exporting: #58
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.187441110610962
# 	Counter: 2900000
# Exporting: #59
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.070709228515625
# 	Counter: 2950000
# Exporting: #60
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.029287099838257
# 	Counter: 3000000
# Exporting: #61
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 8.32821011543274
# 	Counter: 3050000
# Exporting: #62
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.252903938293457
# 	Counter: 3100000
# Exporting: #63
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.332160949707031
# 	Counter: 3150000
# Exporting: #64
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.065846920013428
# 	Counter: 3200000
# Exporting: #65
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.0901713371276855
# 	Counter: 3250000
# Exporting: #66
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 17.735164642333984
# 	Counter: 3300000
# Exporting: #67
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 10.028879404067993
# 	Counter: 3350000
# Exporting: #68
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.730383634567261
# 	Counter: 3400000
# Exporting: #69
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 3.9757442474365234
# 	Counter: 3450000
# Exporting: #70
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.518325567245483
# 	Counter: 3500000
# Exporting: #71
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.444491147994995
# 	Counter: 3550000
# Exporting: #72
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.573310613632202
# 	Counter: 3600000
# Exporting: #73
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.334186315536499
# 	Counter: 3650000
# Exporting: #74
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.058216571807861
# 	Counter: 3700000
# Exporting: #75
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.279267311096191
# 	Counter: 3750000
# Exporting: #76
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.527615547180176
# 	Counter: 3800000
# Exporting: #77
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.443389892578125
# 	Counter: 3850000
# Exporting: #78
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 6.2819788455963135
# 	Counter: 3900000
# Exporting: #79
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.921852588653564
# 	Counter: 3950000
# Exporting: #80
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.469775915145874
# 	Counter: 4000000
# Exporting: #81
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.985766887664795
# 	Counter: 4050000
# Exporting: #82
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.823729515075684
# 	Counter: 4100000
# Exporting: #83
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.104215383529663
# 	Counter: 4150000
# Exporting: #84
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 10.227960348129272
# 	Counter: 4200000
# Exporting: #85
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.163528680801392
# 	Counter: 4250000
# Exporting: #86
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 3.978867769241333
# 	Counter: 4300000
# Exporting: #87
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.24371075630188
# 	Counter: 4350000
# Exporting: #88
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.457132339477539
# 	Counter: 4400000
# Exporting: #89
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.935692310333252
# 	Counter: 4450000
# Exporting: #90
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.281190395355225
# 	Counter: 4500000
# Exporting: #91
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.110770225524902
# 	Counter: 4550000
# Exporting: #92
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.181326866149902
# 	Counter: 4600000
# Exporting: #93
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.499793767929077
# 	Counter: 4650000
# Exporting: #94
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.620948553085327
# 	Counter: 4700000
# Exporting: #95
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 6.079824209213257
# 	Counter: 4750000
# Exporting: #96
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.954899549484253
# 	Counter: 4800000
# Exporting: #97
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.522169351577759
# 	Counter: 4850000
# Exporting: #98
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.986698150634766
# 	Counter: 4900000
# Exporting: #99
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.477097511291504
# 	Counter: 4950000
# Exporting: #100
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.348684310913086
# 	Counter: 5000000
# Exporting: #101
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 11.064327239990234
# 	Counter: 5050000
# Exporting: #102
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.996593952178955
# 	Counter: 5100000
# Exporting: #103
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.326321363449097
# 	Counter: 5150000
# Exporting: #104
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.038382291793823
# 	Counter: 5200000
# Exporting: #105
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.324055194854736
# 	Counter: 5250000
# Exporting: #106
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.052879095077515
# 	Counter: 5300000
# Exporting: #107
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.0002171993255615
# 	Counter: 5350000
# Exporting: #108
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 7.76491379737854
# 	Counter: 5400000
# Exporting: #109
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.247240543365479
# 	Counter: 5450000
# Exporting: #110
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.221736431121826
# 	Counter: 5500000
# Exporting: #111
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.051000356674194
# 	Counter: 5550000
# Exporting: #112
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.2422144412994385
# 	Counter: 5600000
# Exporting: #113
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.059533596038818
# 	Counter: 5650000
# Exporting: #114
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.857476472854614
# 	Counter: 5700000
# Exporting: #115
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.016110420227051
# 	Counter: 5750000
# Exporting: #116
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.010565757751465
# 	Counter: 5800000
# Exporting: #117
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.27026081085205
# 	Counter: 5850000
# Exporting: #118
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.41457986831665
# 	Counter: 5900000
# Exporting: #119
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.383146047592163
# 	Counter: 5950000
# Exporting: #120
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.844733476638794
# 	Counter: 6000000
# Exporting: #121
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 8.92743992805481
# 	Counter: 6050000
# Exporting: #122
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.157165050506592
# 	Counter: 6100000
# Exporting: #123
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.379261493682861
# 	Counter: 6150000
# Exporting: #124
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.272195100784302
# 	Counter: 6200000
# Exporting: #125
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 6.250714063644409
# 	Counter: 6250000
# Exporting: #126
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.767257690429688
# 	Counter: 6300000
# Exporting: #127
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.429601669311523
# 	Counter: 6350000
# Exporting: #128
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.988398790359497
# 	Counter: 6400000
# Exporting: #129
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.10586142539978
# 	Counter: 6450000
# Exporting: #130
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.367475509643555
# 	Counter: 6500000
# Exporting: #131
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 10.197298049926758
# 	Counter: 6550000
# Exporting: #132
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.147916316986084
# 	Counter: 6600000
# Exporting: #133
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.104308605194092
# 	Counter: 6650000
# Exporting: #134
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.570850372314453
# 	Counter: 6700000
# Exporting: #135
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.169968843460083
# 	Counter: 6750000
# Exporting: #136
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.963193893432617
# 	Counter: 6800000
# Exporting: #137
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.642844200134277
# 	Counter: 6850000
# Exporting: #138
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 8.226299285888672
# 	Counter: 6900000
# Exporting: #139
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.303614616394043
# 	Counter: 6950000
# Exporting: #140
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.839966297149658
# 	Counter: 7000000
# Exporting: #141
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.102636337280273
# 	Counter: 7050000
# Exporting: #142
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 5.222177743911743
# 	Counter: 7100000
# Exporting: #143
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.01266884803772
# 	Counter: 7150000
# Exporting: #144
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.764829397201538
# 	Counter: 7200000
# Exporting: #145
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.541819095611572
# 	Counter: 7250000
# Exporting: #146
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.021665096282959
# 	Counter: 7300000
# Exporting: #147
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.147347688674927
# 	Counter: 7350000
# Exporting: #148
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.608884334564209
# 	Counter: 7400000
# Exporting: #149
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.336860179901123
# 	Counter: 7450000
# Exporting: #150
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.743467569351196
# 	Counter: 7500000
# Exporting: #151
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.422214031219482
# 	Counter: 7550000
# Exporting: #152
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.17792010307312
# 	Counter: 7600000
# Exporting: #153
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.199790716171265
# 	Counter: 7650000
# Exporting: #154
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.324087142944336
# 	Counter: 7700000
# Exporting: #155
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 6.934330463409424
# 	Counter: 7750000
# Exporting: #156
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.40363883972168
# 	Counter: 7800000
# Exporting: #157
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.233676671981812
# 	Counter: 7850000
# Exporting: #158
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.1942455768585205
# 	Counter: 7900000
# Exporting: #159
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.952740907669067
# 	Counter: 7950000
# Exporting: #160
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.14036512374878
# 	Counter: 8000000
# Exporting: #161
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 10.10634469985962
# 	Counter: 8050000
# Exporting: #162
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.209965467453003
# 	Counter: 8100000
# Exporting: #163
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.380443811416626
# 	Counter: 8150000
# Exporting: #164
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.315973281860352
# 	Counter: 8200000
# Exporting: #165
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.360225915908813
# 	Counter: 8250000
# Exporting: #166
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.591107368469238
# 	Counter: 8300000
# Exporting: #167
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.226849555969238
# 	Counter: 8350000
# Exporting: #168
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.031907081604004
# 	Counter: 8400000
# Exporting: #169
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.233752727508545
# 	Counter: 8450000
# Exporting: #170
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.484913349151611
# 	Counter: 8500000
# Exporting: #171
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 'utf-8' codec can't encode characters in position 231084-231085: surrogates not allowed
# 	Export time (s): 1.4520025253295898
# 	Counter: 8550000
# Traceback (most recent call last):
#   File "<ipython-input-2-e92284ccb91b>", line 9, in q
#     curs.execute(query)
# UnicodeEncodeError: 'utf-8' codec can't encode characters in position 231084-231085: surrogates not allowed
# Exporting: #172
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# ...
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.047962427139282
# 	Counter: 9150000
# Exporting: #184
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.689865589141846
# 	Counter: 9200000
# Exporting: #185
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 8.193394899368286
# 	Counter: 9250000
# Exporting: #186
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.209895610809326
# 	Counter: 9300000
# Exporting: #187
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.984186172485352
# 	Counter: 9350000
# Exporting: #188
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.717479467391968
# 	Counter: 9400000
# Exporting: #189
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 5.4935595989227295
# 	Counter: 9450000
# Exporting: #190
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.064925909042358
# 	Counter: 9500000
# Exporting: #191
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.824841499328613
# 	Counter: 9550000
# Exporting: #192
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.391268014907837
# 	Counter: 9600000
# Exporting: #193
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.464317321777344
# 	Counter: 9650000
# Exporting: #194
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.173629999160767
# 	Counter: 9700000
# Exporting: #195
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.500483989715576
# 	Counter: 9750000
# Exporting: #196
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.205388069152832
# 	Counter: 9800000
# Exporting: #197
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.488633871078491
# 	Counter: 9850000
# Exporting: #198
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.90980839729309
# 	Counter: 9900000
# Exporting: #199
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.314109325408936
# 	Counter: 9950000
# Exporting: #200
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.860250473022461
# 	Counter: 10000000
# Exporting: #201
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.793175935745239
# 	Counter: 10050000
# Exporting: #202
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 7.9440977573394775
# 	Counter: 10100000
# Exporting: #203
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.356032848358154
# 	Counter: 10150000
# Exporting: #204
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.858449697494507
# 	Counter: 10200000
# Exporting: #205
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.1519012451171875
# 	Counter: 10250000
# Exporting: #206
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.413227319717407
# 	Counter: 10300000
# Exporting: #207
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.274918556213379
# 	Counter: 10350000
# Exporting: #208
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.984915018081665
# 	Counter: 10400000
# Exporting: #209
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.526795387268066
# 	Counter: 10450000
# Exporting: #210
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.1278533935546875
# 	Counter: 10500000
# Exporting: #211
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.634670495986938
# 	Counter: 10550000
# Exporting: #212
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.932494401931763
# 	Counter: 10600000
# Exporting: #213
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.429306507110596
# 	Counter: 10650000
# Exporting: #214
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.587803363800049
# 	Counter: 10700000
# Exporting: #215
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.94762372970581
# 	Counter: 10750000
# Exporting: #216
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.05819058418274
# 	Counter: 10800000
# Exporting: #217
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.315415859222412
# 	Counter: 10850000
# Exporting: #218
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.539186477661133
# 	Counter: 10900000
# Exporting: #219
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 7.259840965270996
# 	Counter: 10950000
# Exporting: #220
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 11.518258810043335
# 	Counter: 11000000
# Exporting: #221
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.327157020568848
# 	Counter: 11050000
# Exporting: #222
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.049727916717529
# 	Counter: 11100000
# Exporting: #223
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 4.833925247192383
# 	Counter: 11150000
# Exporting: #224
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.089146137237549
# 	Counter: 11200000
# Exporting: #225
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 10.009279251098633
# 	Counter: 11250000
# Exporting: #226
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.0951197147369385
# 	Counter: 11300000
# Exporting: #227
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 3.9275400638580322
# 	Counter: 11350000
# Exporting: #228
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.714098691940308
# 	Counter: 11400000
# Exporting: #229
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.19622254371643
# 	Counter: 11450000
# Exporting: #230
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.56959080696106
# 	Counter: 11500000
# Exporting: #231
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 5.35365104675293
# 	Counter: 11550000
# Exporting: #232
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 8.674497127532959
# 	Counter: 11600000
# Exporting: #233
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 10.279941320419312
# 	Counter: 11650000
# Exporting: #234
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 8.802968740463257
# 	Counter: 11700000
# Exporting: #235
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 7.539903402328491
# 	Counter: 11750000
# Exporting: #236
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 5.807802677154541
# 	Counter: 11800000
# Exporting: #237
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	Export time (s): 9.836336135864258
# 	Counter: 11850000
# Exporting: #238
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 9.9752357006073
# 	Counter: 11900000
# Exporting: #239
# 	#Sending Authors#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Editions#
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	#Sending Works#
# 	formatting lines
# 	generating query
# 	querying
# 	Export time (s): 6.909451961517334
# 	Counter: 11950000
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	formatting lines
# 	generating query
# 	querying
# 		No data
# 	formatting lines
# 	generating query
# 	querying
# True

# %%
last_position
# Out:
# 16130758070

# %%
len(exceptions)
# Out:
# 852

# %%
globals()

# %%
import random

attributes = ['tall', 'short', 'big', 'small', 'long', 'dumb', 'smart', 'giraffey', 'giraffeless', 'left-handed', 'right-handed']

lists = []

for x in range(0,50000):
    att_list = []
    for y in range(0,10):
        att_list.append(random.choice(attributes))
        
    lists.append(att_list)

# %%
def join1(input_list):
    base = 'big giraffe is: '
    
    start = t.time()
    
    counter = 0
    for sub_list in input_list:
        base = base + '('+','.join(sub_list)+'), '
        counter += 1
        if (counter % 10000 == 0):
            print('Counter:{}, Run time (s): {}'.format(counter, t.time()-start))
     
    return base


def join2(input_list):
    base = 'big giraffe is: '
    
    start = t.time()
    processed = []
    
    counter = 0
    for sub_list in input_list:
        processed.append('('+','.join(sub_list)+'), ')
        counter += 1
        if (counter % 10000 == 0):
            print('Counter:{}, Run time (s): {}'.format(counter, t.time()-start))
        
    base = base + ''.join(processed)
    
    return base

# %%
import time as t

# %%
start = t.time()
results1 = join1(lists)
print('Run time (s): {}'.format(t.time()-start))
# Out:
# Counter:10000, Run time (s): 0.2890200614929199
# Counter:20000, Run time (s): 6.906020402908325
# Counter:30000, Run time (s): 21.157018899917603
# Counter:40000, Run time (s): 40.78099799156189
# Counter:50000, Run time (s): 66.7850193977356
# Run time (s): 66.78598737716675

# %%
start = t.time()
results2 = join2(lists)
print('Run time (s): {}'.format(t.time()-start))
# Out:
# Counter:10000, Run time (s): 0.010001420974731445
# Counter:20000, Run time (s): 0.019001483917236328
# Counter:30000, Run time (s): 0.0279996395111084
# Counter:40000, Run time (s): 0.03900146484375
# Counter:50000, Run time (s): 0.05100059509277344
# Run time (s): 0.07000064849853516

# %%
results1 == results2
# Out:
# True

# %%
data_query_w = """
    SELECT *
    FROM "works"
    WHERE "WorkTitle" ILIKE '%harry potter and the prisoner of azkaban%'
    LIMIT 10
"""

# %%
data_query_e = """
    SELECT *
    FROM "editions"
    WHERE "EditionTitle" ILIKE '%harry potter and the prisoner of azkaban%'
    LIMIT 10
"""

# %%
w = q(data_query_w, verbosity=True)
e = q(data_query_e, verbosity=True)

# %%
# Out:
# False

# %%
for x,y in zip(w,e):
    print(x)
    print(y)
    print()
# Out:
# ('Harry Potter and the Prisoner of Azkaban', ['{type: {key: /type/author_role}, author: {key: /authors/OL23919A}}'], ['NULL'], '{type: /type/text, value: See https://openlibrary.org/works/OL13716956W/Harry_Potter_and_the_Prisoner_of_Azkaban}', '-1', ['NULL'], ['NULL'], ['NULL'], 1817637)
# ('Harry Potter and the Prisoner of Azkaban', ['NULL'], ['NULL'], ['NULL'], '2010 November', '[Bloomsbury]', 0, 0, 0, ['NULL'], ['NULL'], '-1', ['NULL'], ['NULL'], ['{key: /works/OL13716956W}'], ['{key: /languages/eng}'], '[9781408810569]', 638458)
#
# ('Harry Potter and the Prisoner of Azkaban', ['{type: {key: /type/author_role}, author: {key: /authors/OL23919A}}'], ['NULL'], '{type: /type/text, value: https://openlibrary.org/works/OL13716956W/Harry_Potter_and_the_Prisoner_of_Azkaban}', '-1', ['NULL'], ['NULL'], ['NULL'], 1972925)
# ('Harry Potter and the Prisoner of Azkaban - Hufflepuff Edition', ['{key: /authors/OL23919A}'], ['NULL'], ['NULL'], '2019', '[Bloomsbury]', 0, 0, 0, ['NULL'], ['NULL'], '-1', ['NULL'], ['NULL'], ['{key: /works/OL20145744W}'], ['NULL'], '[9781526606204]', 1634305)
#
# ('Harry Potter and the Prisoner of Azkaban 2005 Wall Calendar', ['{type: /type/author_role, author: {key: /authors/OL2812708A}}'], ['NULL'], '-1', '-1', ['NULL'], ['NULL'], ['NULL'], 2012760)
# ('Harry Potter and the Prisoner of Azkaban', ['NULL'], ['NULL'], ['NULL'], '2014 September', '[Bloomsbury]', 0, 0, 0, ['NULL'], ['NULL'], '-1', ['NULL'], ['NULL'], ['{key: /works/OL13716956W}'], ['{key: /languages/eng}'], '[9781408855911]', 1944367)
#
# ('Harry Potter and the Prisoner of Azkaban', ['{type: {key: /type/author_role}, author: {key: /authors/OL23919A}}'], ['NULL'], '{type: /type/text, value: https://openlibrary.org/works/OL13716956W/Harry_Potter_and_the_Prisoner_of_Azkaban}', '-1', ['NULL'], ['NULL'], ['NULL'], 2331252)
# ('Harry Potter and the Prisoner of Azkaban', ['{key: /authors/OL2735646A}'], ['NULL'], ['Teaching of a specific subject'], 'October 2001', '[Classroom Resources]', 0, 0, 0, ['NULL'], ['NULL'], '-1', ['NULL'], ['NULL'], ['{key: /works/OL8224434W}'], ['NULL'], '[9781841065267]', 1992456)
#
# ('Harry Potter and the Prisoner of Azkaban', ['{type: {key: /type/author_role}, author: {key: /authors/OL23919A}}'], ['NULL'], '{type: /type/text, value: See https://openlibrary.org/works/OL13716956W}', '-1', ['NULL'], ['NULL'], ['NULL'], 2484089)
# ('Harry Potter and the prisoner of Azkaban by J.K. Rowling', ['{key: /authors/OL583666A}'], ['Juvenile literature'], ['Rowling, J. K.', 'Potter, Harry (Fictitious character) -- Instruction and study -- Juvenile literature', 'Reading (Elementary)'], '2000', '[Scholastic Professional Books]', 16, 0, 0, ['NULL'], ['NULL'], '-1', ['NULL'], ['NULL'], ['{key: /works/OL3494526W}'], ['{key: /languages/eng}'], '-1', 2010437)
#
# ('Harry Potter and the Prisoner of Azkaban', ['{type: {key: /type/author_role}, author: {key: /authors/OL7454240A}}'], ['NULL'], '-1', '-1', ['NULL'], ['NULL'], ['NULL'], 2648653)
# ('Harry Potter and the Prisoner of Azkaban', ['NULL'], ['NULL'], ['NULL'], '2015', '[Pottermore Limited]', 0, 0, 0, ['NULL'], ['NULL'], '-1', ['NULL'], ['NULL'], ['{key: /works/OL13716956W}'], ['{key: /languages/eng}'], '[9781781100516]', 2215759)
#
# ('Harry Potter and the Prisoner of Azkaban', ['{type: {key: /type/author_role}, author: {key: /authors/OL23919A}}'], ['NULL'], '{type: /type/text, value: https://openlibrary.org/works/OL13716956W/Harry_Potter_and_the_Prisoner_of_Azkaban}', '-1', ['NULL'], ['NULL'], ['NULL'], 2853525)
# ('Harry Potter and the Prisoner of Azkaban: Signature Edition', ['{key: /authors/OL23919A}'], ['NULL'], ['NULL'], 'Aug 27, 2010', '[Bloomsbury Publishing Plc]', 0, 0, 0, ['NULL'], ['NULL'], '-1', ['NULL'], ['NULL'], ['{key: /works/OL20109752W}'], ['NULL'], '[9781408812839]', 2531662)
#
# ('Harry Potter and the Prisoner of Azkaban', ['{type: {key: /type/author_role}, author: {key: /authors/OL23919A}}'], ['NULL'], '{type: /type/text, value: https://openlibrary.org/works/OL13716956W/Harry_Potter_and_the_Prisoner_of_Azkaban}', '-1', ['NULL'], ['NULL'], ['NULL'], 3071811)
# ('Harry Potter and the Prisoner of Azkaban', ['NULL'], ['NULL'], ['NULL'], '2000', '[Bloomsbury]', 0, 0, 0, ['NULL'], ['NULL'], '-1', ['NULL'], ['NULL'], ['{key: /works/OL13716956W}'], ['{key: /languages/eng}'], '[9780747546344]', 3154471)
#
# ('Harry Potter and the Prisoner of Azkaban', ['{type: {key: /type/author_role}, author: {key: /authors/OL23919A}}'], ['NULL'], '{type: /type/text, value: https://openlibrary.org/works/OL13716956W/Harry_Potter_and_the_Prisoner_of_Azkaban}', '-1', ['NULL'], ['NULL'], ['NULL'], 3219861)
# ('Harry Potter and the Prisoner of Azkaban', ['NULL'], ['NULL'], ['NULL'], '2001', '[Scholastic]', 435, 0, 0, ['NULL'], ['NULL'], '-1', ['NULL'], ['NULL'], ['{key: /works/OL13716956W}'], ['{key: /languages/eng}'], '[9780439136365]', 3251309)
#
# ('Harry Potter and the Prisoner of Azkaban', ['{type: {key: /type/author_role}, author: {key: /authors/OL23919A}}'], ['NULL'], '{type: /type/text, value: https://openlibrary.org/works/OL13716956W/Harry_Potter_and_the_Prisoner_of_Azkaban}', '-1', ['NULL'], ['NULL'], ['NULL'], 3219862)
# ('Harry Potter and the Prisoner of Azkaban', ['{key: /authors/OL23919A}'], ['NULL'], ['NULL'], '2001 September', '[Scholastic]', 0, 0, 0, ['NULL'], ['NULL'], '-1', ['NULL'], ['NULL'], ['{key: /works/OL13716956W}'], ['{key: /languages/eng}'], '[9780439321488]', 3283712)

# %%
import requests

# %%
s = 'https://www.googleapis.com/books/v1/volumes?q=flowers+inauthor'

r = requests.request('GET', s)

# %%
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 3288,
#  'items': [{'kind': 'books#volume',
#    'id': 'cRYjgfymePYC',
#    'etag': 'DLan+WG7zdU',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/cRYjgfymePYC',
#    'volumeInfo': {'title': 'The War Of The Flowers',
#     'authors': ['Tad Williams'],
#     'publisher': 'Penguin',
#     'publishedDate': '2006-09-05',
#     'description': "Theo Vilmos' life is about to take a real turn for the worse. He is drawn from his home in Northern California into the parallel world of Faerie, for, unknown to him, he is a pivotal figure in a war between certain of Faerie's powerful lords and the rest of the strange creatures who live in this exotic realm.",
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781101657645'},
#      {'type': 'ISBN_10', 'identifier': '1101657642'}],
#     'readingModes': {'text': True, 'image': False},
#     'pageCount': 832,
#     'printType': 'BOOK',
#     'categories': ['Fiction'],
#     'averageRating': 4.0,
#     'ratingsCount': 20,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': True,
#     'contentVersion': '1.2.2.0.preview.2',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=cRYjgfymePYC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=cRYjgfymePYC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=cRYjgfymePYC&printsec=frontcover&dq=flowers+inauthor&hl=&cd=1&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=cRYjgfymePYC&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=cRYjgfymePYC'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'retailPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'buyLink': 'https://play.google.com/store/books/details?id=cRYjgfymePYC&rdid=book-cRYjgfymePYC&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/The_War_Of_The_Flowers-sample-epub.acsm?id=cRYjgfymePYC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=cRYjgfymePYC&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Theo Vilmos&#39; life is about to take a real turn for the worse.'}},
#   {'kind': 'books#volume',
#    'id': 'a1NGAQAAMAAJ',
#    'etag': 'wms58KCxRQI',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/a1NGAQAAMAAJ',
#    'volumeInfo': {'title': 'Trippings in Author-land',
#     'authors': ['Emily Chubbuck Judson'],
#     'publishedDate': '1846',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'MINN:31951002102843U'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 281,
#     'printType': 'BOOK',
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.1.3.0.full.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=a1NGAQAAMAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=a1NGAQAAMAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=a1NGAQAAMAAJ&pg=PA208&dq=flowers+inauthor&hl=&cd=2&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=a1NGAQAAMAAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=a1NGAQAAMAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FREE',
#     'isEbook': True,
#     'buyLink': 'https://play.google.com/store/books/details?id=a1NGAQAAMAAJ&rdid=book-a1NGAQAAMAAJ&rdot=1&source=gbs_api'},
#    'accessInfo': {'country': 'US',
#     'viewability': 'ALL_PAGES',
#     'embeddable': True,
#     'publicDomain': True,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False,
#      'downloadLink': 'http://books.google.com/books/download/Trippings_in_Author_land.epub?id=a1NGAQAAMAAJ&hl=&output=epub&source=gbs_api'},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=a1NGAQAAMAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'FULL_PUBLIC_DOMAIN',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Hope is a butterfly, and Imagination loves to chase it from <b>flower</b> to <b>flower</b>, and <br>\nfrom glitter to glitter; but Memory is an angel, that comes in the holy night-time; <br>\nand, folding its wings beside us, forges, silently, those golden links, which, as <br>\nyears&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': 'Vrl13goK-VcC',
#    'etag': 'uJzJSIeJPpI',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/Vrl13goK-VcC',
#    'volumeInfo': {'title': 'How to Photograph Flowers',
#     'authors': ['Heather Angel'],
#     'publisher': 'Stackpole Books',
#     'publishedDate': '1998',
#     'description': 'Heather Angel, internationally known nature photographer and author, describes equipment, film, lighting, composition, and special techniques for photographing flowers in the wild and in gardens. Straightforward explanations focus on the particular challenges of taking beautiful flower photographs, such as wind, light, and problem colors. The book also includes tips on making money from nature photography. 131 color photos.',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0811724557'},
#      {'type': 'ISBN_13', 'identifier': '9780811724555'}],
#     'readingModes': {'text': False, 'image': True},
#     'pageCount': 131,
#     'printType': 'BOOK',
#     'categories': ['Photography'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.0.1.0.preview.1',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=Vrl13goK-VcC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=Vrl13goK-VcC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=Vrl13goK-VcC&pg=PA15&dq=flowers+inauthor&hl=&cd=3&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=Vrl13goK-VcC&dq=flowers+inauthor&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/How_to_Photograph_Flowers.html?hl=&id=Vrl13goK-VcC'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=Vrl13goK-VcC&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Water lily (Nymphaea &quot;Attraction&quot;) <b>in author&#39;s</b> garden pond, Surrey, England,. ()-. <br>\nP. A. R. T. •. T. W. (). Cameras <b>Flowers</b> can be photographed using any type of <br>\ncamera, from a simple point-andshoot to a 4x5-inch view camera or an even <br>\nlarger&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': '2SYhAQAAIAAJ',
#    'etag': 'ryZHSZ80Fbw',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/2SYhAQAAIAAJ',
#    'volumeInfo': {'title': 'Catalog of Copyright Entries',
#     'subtitle': 'Third series',
#     'publishedDate': '1951',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'STANFORD:36105006281351'}],
#     'readingModes': {'text': False, 'image': True},
#     'printType': 'BOOK',
#     'categories': ['Copyright'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '1.1.1.0.full.1',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=2SYhAQAAIAAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=2SYhAQAAIAAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=2SYhAQAAIAAJ&pg=PA148&dq=flowers+inauthor&hl=&cd=4&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=2SYhAQAAIAAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=2SYhAQAAIAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FREE',
#     'isEbook': True,
#     'buyLink': 'https://play.google.com/store/books/details?id=2SYhAQAAIAAJ&rdid=book-2SYhAQAAIAAJ&rdot=1&source=gbs_api'},
#    'accessInfo': {'country': 'US',
#     'viewability': 'ALL_PAGES',
#     'embeddable': True,
#     'publicDomain': True,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=2SYhAQAAIAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'FULL_PUBLIC_DOMAIN',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'DISNEY (WALT) PRODUCTIONS. Alice in Wonderland meets the enchanted <br>\n<b>flowers</b>. ... Burbank, Calif.; 5Sep51; K30137. White Rabbit and the <b>flowers</b>. ... 7 x <br>\n7 <b>in. Author</b> of reproduction: Brown and Bigelow. © Brown &amp; Bigelow, St. Paul;&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': 'AsM4Q8u1OgUC',
#    'etag': '3SBTq8VktS4',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/AsM4Q8u1OgUC',
#    'volumeInfo': {'title': 'Library Bulletin',
#     'authors': ['Fitchburg Public Library'],
#     'publishedDate': '1896',
#     'industryIdentifiers': [{'type': 'OTHER',
#       'identifier': 'UIUC:30112042813524'}],
#     'readingModes': {'text': False, 'image': True},
#     'printType': 'BOOK',
#     'categories': ['Catalogs, Classified'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'full-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=AsM4Q8u1OgUC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=AsM4Q8u1OgUC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=AsM4Q8u1OgUC&pg=RA1-PA8&dq=flowers+inauthor&hl=&cd=5&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=AsM4Q8u1OgUC&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=AsM4Q8u1OgUC'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FREE',
#     'isEbook': True,
#     'buyLink': 'https://play.google.com/store/books/details?id=AsM4Q8u1OgUC&rdid=book-AsM4Q8u1OgUC&rdot=1&source=gbs_api'},
#    'accessInfo': {'country': 'US',
#     'viewability': 'ALL_PAGES',
#     'embeddable': True,
#     'publicDomain': True,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=AsM4Q8u1OgUC&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'FULL_PUBLIC_DOMAIN',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': '595.7 W. Stories Of <b>Flowers</b>, Trees, Birds and Insects for the Younger Readers. <br>\nEssays and Studies. Ewing, J. H. (G.) Blackbird&#39;s nest. (<b>In author&#39;s</b> Melchior&#39;s <br>\ndream. p. 25.) 2 JE21 —Dandelion clocks. 2 JE23 Lindsay, B. About robins: <br>\nsongs,&nbsp;...'}},
#   {'kind': 'books#volume',
#    'id': 'ybt2ho-JH6QC',
#    'etag': '6lDKz4BwZzQ',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/ybt2ho-JH6QC',
#    'volumeInfo': {'title': 'Chadha',
#     'subtitle': 'The Story of an Epic Constitutional Struggle',
#     'authors': ['Barbara Hinkson Craig'],
#     'publisher': 'Univ of California Press',
#     'publishedDate': '1990-03-05',
#     'description': 'Looks at how the case of a Kenyan student led to the ruling that the legislative veto in the Immigration and Naturalization Act is unconstitutional',
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0520069552'},
#      {'type': 'ISBN_13', 'identifier': '9780520069558'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 284,
#     'printType': 'BOOK',
#     'categories': ['History'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.0.3.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=ybt2ho-JH6QC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=ybt2ho-JH6QC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=ybt2ho-JH6QC&pg=PA244&dq=flowers+inauthor&hl=&cd=6&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=ybt2ho-JH6QC&dq=flowers+inauthor&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Chadha.html?hl=&id=ybt2ho-JH6QC'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Chadha-sample-epub.acsm?id=ybt2ho-JH6QC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=ybt2ho-JH6QC&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Copy of Rodino letter, provided by Pohlmann, <b>in author&#39;s</b> files. 43. Deportation <br>\nHearings, pp. ... 5. 49. Ibid., pp. 1-2. 50. Copy of Chadha&#39;s deportation notice <b>in</b> <br>\n<b>author&#39;s</b> files. 51. ... (Hereafter cited as <b>Flowers</b> Hearings.) 3. Ibid., p. 140. 4. Ibid., <br>\np.'}},
#   {'kind': 'books#volume',
#    'id': 'l4aXgduXgwUC',
#    'etag': 'uHx1xsVy/GA',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/l4aXgduXgwUC',
#    'volumeInfo': {'title': 'Full Many a Flower',
#     'authors': ['Ruby Dayton'],
#     'publisher': 'iUniverse',
#     'publishedDate': '2000-09-01',
#     'description': "In the aftermath of the Great Depression, two year old Molly Whittaker's mother dies and leaves her in the care of her father, Truman, and her two brothers. Truman is desperate to keep his family together but when World War 2 begins, his older son joins and his younger son takes residence with his uncle. Truman and Molly roam the banks of the Mississippi river, he works clearing new ground and picking cotton until he gets a job operating a ferry. But, after a steamer collides with his vessel he fears for Molly's life and tries to find work elsewhere. Truman meets with a farm couple and they persuaded him to leave Molly with them. After a few years, Truman returns with a gypsy wife and her three adolescent sons. Molly is torn from a caring home and thrust into the clutches of this strange family. The Whittaker's take to the road as migrant field workers. A tent provides the only roof over their heads. Periodically, they miscalculate the harvest seasons and fine themselves destitute and near starvation. Truman soon discovers Manita ,his wife, is a soliciting prostitute and chooses to ignore the fact due to the much needed money. During a harrowing drunken episode, Manita pins Truman to the floor with a knife though his chest. Molly witnesses the event. At eight she is orphaned. Molly suffers bells palsy, leaving her face distorted. She refuses to speak. A mute, her teacher labels her incapable of learning and sends her home. Molly grows up illiterate. After the war is over, she comes to live with her brother and his wife, in the foothills of the Appalachian mountains. There, Molly triumphs over her years of adversity and becomes a prominent southern artist. She acquires an education and finds romance, love and stability..",
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780595138135'},
#      {'type': 'ISBN_10', 'identifier': '0595138136'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 372,
#     'printType': 'BOOK',
#     'categories': ['Fiction'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '2.3.3.0.preview.3',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=l4aXgduXgwUC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=l4aXgduXgwUC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=l4aXgduXgwUC&pg=PA361&dq=flowers+inauthor&hl=&cd=7&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=l4aXgduXgwUC&dq=flowers+inauthor&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Full_Many_a_Flower.html?hl=&id=l4aXgduXgwUC'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Full_Many_a_Flower-sample-epub.acsm?id=l4aXgduXgwUC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=l4aXgduXgwUC&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'To further her understanding of writing she enrolled <b>in author</b> Iean Ridley&#39;s fiction <br>\nwriting courses. There she begin Eull Many a <b>Flower</b>, her first book of “faction”. In <br>\nthe aftermath of the Great Depression, two year old. 361 About the Author.'}},
#   {'kind': 'books#volume',
#    'id': 'TngBSXx5J-kC',
#    'etag': 'ZYhPnjNZPWo',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/TngBSXx5J-kC',
#    'volumeInfo': {'title': 'Where Have All the Flower Children Gone?',
#     'authors': ['Sandra Gurvis'],
#     'publisher': 'Univ. Press of Mississippi',
#     'publishedDate': '2009-09-18',
#     'description': "What happened to the Vietnam protesters and civil rights activists? Where did their idealism lead them? And what do they feel they have contributed to the nation's political debate? Answers to these and many other questions can be found in the first-hand narratives, history, and photographs of Where Have All the Flower Children Gone? Chapters examine such aspects as the origins of the student protest movement and the conservative backlash as well as the fates of draft evaders, expatriates, and conscientious objectors. Respondents explore the conflict between the various generations over Vietnam, Iraq, and other issues. What happened to the children of the 1960s, and how do they reconcile their pasts with the present? Gurvis examines little-known aspects of the 1960s such as an uprising at Colorado State and coffeehouses that helped soldiers form opinions about Vietnam. Where Have All the Flower Children Gone? puts a contemporary face on the Age of Aquarius. Gurvis interviews such officials as Senator Chuck Hagel (R-Nebraska) and such high-profile former radicals as Bernadine Dohrn. The book also provides one of the last interviews with the late Ossie Davis. The major and minor players of Kent State and Jackson State, where students and others perished at the hands of soldiers, weigh in as well as do the generations preceding and succeeding the Baby Boomers.",
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1604731427'},
#      {'type': 'ISBN_13', 'identifier': '9781604731422'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 240,
#     'printType': 'BOOK',
#     'categories': ['History'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '0.4.4.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=TngBSXx5J-kC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=TngBSXx5J-kC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=TngBSXx5J-kC&pg=PA145&dq=flowers+inauthor&hl=&cd=8&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=TngBSXx5J-kC&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=TngBSXx5J-kC'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 30.0, 'currencyCode': 'USD'},
#     'retailPrice': {'amount': 16.5, 'currencyCode': 'USD'},
#     'buyLink': 'https://play.google.com/store/books/details?id=TngBSXx5J-kC&rdid=book-TngBSXx5J-kC&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 30000000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 16500000.0, 'currencyCode': 'USD'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True},
#     'pdf': {'isAvailable': True},
#     'webReaderLink': 'http://play.google.com/books/reader?id=TngBSXx5J-kC&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'I never flnished college and encountered discrimination, particularly [during times<br>\n] when long hair was out and dressing for success was <b>in” (author</b> interview). 4. <br>\nThe song could also apply to the hundreds of thousands. 145.'}},
#   {'kind': 'books#volume',
#    'id': '7-GgBwAAQBAJ',
#    'etag': 'hHysNPjPITI',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/7-GgBwAAQBAJ',
#    'volumeInfo': {'title': 'Sidewalk Flowers',
#     'authors': ['JonArno Lawson'],
#     'publisher': 'Groundwood Books Ltd',
#     'publishedDate': '2015-03-27',
#     'description': "Winner of the Governor General's Literary Award for Children's Illustrated Book A New York Times Best Illustrated Children's Book of the Year In this wordless picture book, a little girl collects wildflowers while her distracted father pays her little attention. Each flower becomes a gift, and whether the gift is noticed or ignored, both giver and recipient are transformed by their encounter. “Written” by award-winning poet JonArno Lawson and brought to life by illustrator Sydney Smith, Sidewalk Flowers is an ode to the importance of small things, small people and small gestures.",
#     'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781554988556'},
#      {'type': 'ISBN_10', 'identifier': '1554988551'}],
#     'readingModes': {'text': True, 'image': True},
#     'pageCount': 32,
#     'printType': 'BOOK',
#     'categories': ['Juvenile Fiction'],
#     'averageRating': 3.5,
#     'ratingsCount': 4,
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': '1.1.1.0.preview.3',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=7-GgBwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=7-GgBwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=7-GgBwAAQBAJ&printsec=frontcover&dq=flowers+inauthor&hl=&cd=9&source=gbs_api',
#     'infoLink': 'https://play.google.com/store/books/details?id=7-GgBwAAQBAJ&source=gbs_api',
#     'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=7-GgBwAAQBAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'FOR_SALE',
#     'isEbook': True,
#     'listPrice': {'amount': 14.95, 'currencyCode': 'USD'},
#     'retailPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'buyLink': 'https://play.google.com/store/books/details?id=7-GgBwAAQBAJ&rdid=book-7-GgBwAAQBAJ&rdot=1&source=gbs_api',
#     'offers': [{'finskyOfferType': 1,
#       'listPrice': {'amountInMicros': 14950000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'},
#       'giftable': True}]},
#    'accessInfo': {'country': 'US',
#     'viewability': 'PARTIAL',
#     'embeddable': True,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Sidewalk_Flowers-sample-epub.acsm?id=7-GgBwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'pdf': {'isAvailable': True,
#      'acsTokenLink': 'http://books.google.com/books/download/Sidewalk_Flowers-sample-pdf.acsm?id=7-GgBwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api'},
#     'webReaderLink': 'http://play.google.com/books/reader?id=7-GgBwAAQBAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'SAMPLE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'Winner of the Governor General&#39;s Literary Award for Children&#39;s Illustrated Book A New York Times Best Illustrated Children&#39;s Book of the Year In this wordless picture book, a little girl collects wildflowers while her distracted father pays ...'}},
#   {'kind': 'books#volume',
#    'id': '18ioPAAACAAJ',
#    'etag': '2qMyCJ7aOvk',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/18ioPAAACAAJ',
#    'volumeInfo': {'title': 'The Case of the Flowers That Make Your Body All Wobbly',
#     'authors': ['Enid Blyton'],
#     'publisher': "Hodder Children's Books",
#     'publishedDate': '2009-01-01',
#     'description': "There are two stories/TV episodes in each book so they are 'flipper' books, with a front cover for each story. THE CASE OF THE FLOWERS THAT MAKE YOUR BODY ALL WOBBLY A mysterious rose blight is affecting people, too THE CASE OF THE GUY WHO LOOKS PRETTY GOOD FOR A 2000-YEAR-OLD Is the mummified mariner genuinely ancient?",
#     'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0340970863'},
#      {'type': 'ISBN_13', 'identifier': '9780340970867'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 144,
#     'printType': 'BOOK',
#     'categories': ['Adventure stories, English'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=18ioPAAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=18ioPAAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'language': 'en',
#     'previewLink': 'http://books.google.com/books?id=18ioPAAACAAJ&dq=flowers+inauthor&hl=&cd=10&source=gbs_api',
#     'infoLink': 'http://books.google.com/books?id=18ioPAAACAAJ&dq=flowers+inauthor&hl=&source=gbs_api',
#     'canonicalVolumeLink': 'https://books.google.com/books/about/The_Case_of_the_Flowers_That_Make_Your_B.html?hl=&id=18ioPAAACAAJ'},
#    'saleInfo': {'country': 'US',
#     'saleability': 'NOT_FOR_SALE',
#     'isEbook': False},
#    'accessInfo': {'country': 'US',
#     'viewability': 'NO_PAGES',
#     'embeddable': False,
#     'publicDomain': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'webReaderLink': 'http://play.google.com/books/reader?id=18ioPAAACAAJ&hl=&printsec=frontcover&source=gbs_api',
#     'accessViewStatus': 'NONE',
#     'quoteSharingAllowed': False},
#    'searchInfo': {'textSnippet': 'THE CASE OF THE FLOWERS THAT MAKE YOUR BODY ALL WOBBLY A mysterious rose blight is affecting people, too THE CASE OF THE GUY WHO LOOKS PRETTY GOOD FOR A 2000-YEAR-OLD Is the mummified mariner genuinely ancient?'}}]}
