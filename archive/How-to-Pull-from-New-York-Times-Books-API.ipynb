# %%
import requests
import json
import pandas as pd
import numpy as np
import time
import helper_functions as hf
from helper_functions import *
import datetime

# %%
payload = {'userId':'1'}
a = requests.get('https://api.readrr.app/api/datasciencetogetasecretandpineapplepizzaandbrocolli/2')

# %%
b = json.loads(a.text)

# %%
aggregate(b,'title')
# Out:
# ['Hooked',
#  'Tiny Habits',
#  'Gödel, Escher, Bach',
#  'WTF?',
#  'Whiplash',
#  'Whiplash',
#  'The Goal',
#  'Measure What Matters',
#  "Man's Search For Meaning"]

# %%
from importlib import reload
from helper_functions import *

# %% [markdown]
# ## Obtain NYT list information
# I'm trying to get bestseller information from the nyt API. They have a variety of lists, and metadata on each list that they have. The metadata is stored in the '/lists/names.json' endpoint. Lets view this metadata first (it will help with looping functionality later when we need details from each sub-list)

# %% [markdown]
# ### Getting the raw information

# %%
from secrets import NYT_API_KEY

# %%
# Hit the API endpoint to get the list of all the lists avalable through the api
book_lists = requests.get('https://api.nytimes.com/svc/books/v3/lists/names.json?api-key=' + NYT_API_KEY)

# %%
# storing list names from API response
listoflists = json.loads(book_lists.text)['results']
listoflists
# Out:
# [{'list_name': 'Combined Print and E-Book Fiction',
#   'display_name': 'Combined Print & E-Book Fiction',
#   'list_name_encoded': 'combined-print-and-e-book-fiction',
#   'oldest_published_date': '2011-02-13',
#   'newest_published_date': '2020-03-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Combined Print and E-Book Nonfiction',
#   'display_name': 'Combined Print & E-Book Nonfiction',
#   'list_name_encoded': 'combined-print-and-e-book-nonfiction',
#   'oldest_published_date': '2011-02-13',
#   'newest_published_date': '2020-03-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Hardcover Fiction',
#   'display_name': 'Hardcover Fiction',
#   'list_name_encoded': 'hardcover-fiction',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2020-03-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Hardcover Nonfiction',
#   'display_name': 'Hardcover Nonfiction',
#   'list_name_encoded': 'hardcover-nonfiction',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2020-03-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Trade Fiction Paperback',
#   'display_name': 'Paperback Trade Fiction',
#   'list_name_encoded': 'trade-fiction-paperback',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2020-03-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Mass Market Paperback',
#   'display_name': 'Paperback Mass-Market Fiction',
#   'list_name_encoded': 'mass-market-paperback',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Paperback Nonfiction',
#   'display_name': 'Paperback Nonfiction',
#   'list_name_encoded': 'paperback-nonfiction',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2020-03-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'E-Book Fiction',
#   'display_name': 'E-Book Fiction',
#   'list_name_encoded': 'e-book-fiction',
#   'oldest_published_date': '2011-02-13',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'E-Book Nonfiction',
#   'display_name': 'E-Book Nonfiction',
#   'list_name_encoded': 'e-book-nonfiction',
#   'oldest_published_date': '2011-02-13',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Hardcover Advice',
#   'display_name': 'Hardcover Advice & Misc.',
#   'list_name_encoded': 'hardcover-advice',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2013-04-21',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Paperback Advice',
#   'display_name': 'Paperback Advice & Misc.',
#   'list_name_encoded': 'paperback-advice',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2013-04-21',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Advice How-To and Miscellaneous',
#   'display_name': 'Advice, How-To & Miscellaneous',
#   'list_name_encoded': 'advice-how-to-and-miscellaneous',
#   'oldest_published_date': '2013-04-28',
#   'newest_published_date': '2020-03-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Hardcover Graphic Books',
#   'display_name': 'Hardcover Graphic Books',
#   'list_name_encoded': 'hardcover-graphic-books',
#   'oldest_published_date': '2009-03-15',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Paperback Graphic Books',
#   'display_name': 'Paperback Graphic Books',
#   'list_name_encoded': 'paperback-graphic-books',
#   'oldest_published_date': '2009-03-15',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Manga',
#   'display_name': 'Manga',
#   'list_name_encoded': 'manga',
#   'oldest_published_date': '2009-03-15',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Combined Print Fiction',
#   'display_name': 'Combined Hardcover & Paperback Fiction',
#   'list_name_encoded': 'combined-print-fiction',
#   'oldest_published_date': '2011-02-13',
#   'newest_published_date': '2013-05-12',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Combined Print Nonfiction',
#   'display_name': 'Combined Hardcover & Paperback Nonfiction',
#   'list_name_encoded': 'combined-print-nonfiction',
#   'oldest_published_date': '2011-02-13',
#   'newest_published_date': '2013-05-12',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Chapter Books',
#   'display_name': 'Children’s Chapter Books',
#   'list_name_encoded': 'chapter-books',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2012-12-09',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Childrens Middle Grade',
#   'display_name': 'Children’s Middle Grade',
#   'list_name_encoded': 'childrens-middle-grade',
#   'oldest_published_date': '2012-12-16',
#   'newest_published_date': '2015-08-23',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Childrens Middle Grade E-Book',
#   'display_name': 'Children’s Middle Grade E-Book',
#   'list_name_encoded': 'childrens-middle-grade-e-book',
#   'oldest_published_date': '2015-08-30',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Childrens Middle Grade Hardcover',
#   'display_name': 'Children’s Middle Grade Hardcover',
#   'list_name_encoded': 'childrens-middle-grade-hardcover',
#   'oldest_published_date': '2015-08-30',
#   'newest_published_date': '2020-03-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Childrens Middle Grade Paperback',
#   'display_name': 'Children’s Middle Grade Paperback',
#   'list_name_encoded': 'childrens-middle-grade-paperback',
#   'oldest_published_date': '2015-08-30',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Paperback Books',
#   'display_name': 'Children’s Paperback Books',
#   'list_name_encoded': 'paperback-books',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2012-12-09',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Picture Books',
#   'display_name': 'Children’s Picture Books',
#   'list_name_encoded': 'picture-books',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2020-03-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Series Books',
#   'display_name': 'Children’s Series',
#   'list_name_encoded': 'series-books',
#   'oldest_published_date': '2008-06-08',
#   'newest_published_date': '2020-03-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Young Adult',
#   'display_name': 'Young Adult',
#   'list_name_encoded': 'young-adult',
#   'oldest_published_date': '2012-12-16',
#   'newest_published_date': '2015-08-23',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Young Adult E-Book',
#   'display_name': 'Young Adult E-Book',
#   'list_name_encoded': 'young-adult-e-book',
#   'oldest_published_date': '2015-08-30',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Young Adult Hardcover',
#   'display_name': 'Young Adult Hardcover',
#   'list_name_encoded': 'young-adult-hardcover',
#   'oldest_published_date': '2015-08-30',
#   'newest_published_date': '2020-03-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Young Adult Paperback',
#   'display_name': 'Young Adult Paperback',
#   'list_name_encoded': 'young-adult-paperback',
#   'oldest_published_date': '2015-08-30',
#   'newest_published_date': '2017-01-29',
#   'updated': 'WEEKLY'},
#  {'list_name': 'Animals',
#   'display_name': 'Animals',
#   'list_name_encoded': 'animals',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Audio Fiction',
#   'display_name': 'Audio Fiction',
#   'list_name_encoded': 'audio-fiction',
#   'oldest_published_date': '2018-03-11',
#   'newest_published_date': '2020-03-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Audio Nonfiction',
#   'display_name': 'Audio Nonfiction',
#   'list_name_encoded': 'audio-nonfiction',
#   'oldest_published_date': '2018-03-11',
#   'newest_published_date': '2020-03-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Business Books',
#   'display_name': 'Business',
#   'list_name_encoded': 'business-books',
#   'oldest_published_date': '2013-11-03',
#   'newest_published_date': '2020-03-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Celebrities',
#   'display_name': 'Celebrities',
#   'list_name_encoded': 'celebrities',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Crime and Punishment',
#   'display_name': 'Crime and Punishment',
#   'list_name_encoded': 'crime-and-punishment',
#   'oldest_published_date': '2014-10-12',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Culture',
#   'display_name': 'Culture',
#   'list_name_encoded': 'culture',
#   'oldest_published_date': '2014-10-12',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Education',
#   'display_name': 'Education',
#   'list_name_encoded': 'education',
#   'oldest_published_date': '2014-10-12',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Espionage',
#   'display_name': 'Espionage',
#   'list_name_encoded': 'espionage',
#   'oldest_published_date': '2014-12-14',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Expeditions Disasters and Adventures',
#   'display_name': 'Expeditions',
#   'list_name_encoded': 'expeditions-disasters-and-adventures',
#   'oldest_published_date': '2014-12-14',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Fashion Manners and Customs',
#   'display_name': 'Fashion, Manners and Customs',
#   'list_name_encoded': 'fashion-manners-and-customs',
#   'oldest_published_date': '2014-10-12',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Food and Fitness',
#   'display_name': 'Food and Diet',
#   'list_name_encoded': 'food-and-fitness',
#   'oldest_published_date': '2013-09-01',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Games and Activities',
#   'display_name': 'Games and Activities',
#   'list_name_encoded': 'games-and-activities',
#   'oldest_published_date': '2014-10-12',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Graphic Books and Manga',
#   'display_name': 'Graphic Books and Manga',
#   'list_name_encoded': 'graphic-books-and-manga',
#   'oldest_published_date': '2019-10-13',
#   'newest_published_date': '2020-02-16',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Hardcover Business Books',
#   'display_name': 'Hardcover Business Books',
#   'list_name_encoded': 'hardcover-business-books',
#   'oldest_published_date': '2011-07-03',
#   'newest_published_date': '2013-10-13',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Health',
#   'display_name': 'Health',
#   'list_name_encoded': 'health',
#   'oldest_published_date': '2014-10-12',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Humor',
#   'display_name': 'Humor',
#   'list_name_encoded': 'humor',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Indigenous Americans',
#   'display_name': 'Indigenous Americans',
#   'list_name_encoded': 'indigenous-americans',
#   'oldest_published_date': '2014-12-14',
#   'newest_published_date': '2016-01-10',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Relationships',
#   'display_name': 'Love and Relationships',
#   'list_name_encoded': 'relationships',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Mass Market Monthly',
#   'display_name': 'Mass Market',
#   'list_name_encoded': 'mass-market-monthly',
#   'oldest_published_date': '2019-10-13',
#   'newest_published_date': '2020-03-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Middle Grade Paperback Monthly',
#   'display_name': 'Middle Grade Paperback',
#   'list_name_encoded': 'middle-grade-paperback-monthly',
#   'oldest_published_date': '2019-10-13',
#   'newest_published_date': '2020-03-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Paperback Business Books',
#   'display_name': 'Paperback Business Books',
#   'list_name_encoded': 'paperback-business-books',
#   'oldest_published_date': '2011-07-03',
#   'newest_published_date': '2013-10-13',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Family',
#   'display_name': 'Parenthood and Family',
#   'list_name_encoded': 'family',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Hardcover Political Books',
#   'display_name': 'Politics and American History',
#   'list_name_encoded': 'hardcover-political-books',
#   'oldest_published_date': '2011-07-03',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Race and Civil Rights',
#   'display_name': 'Race and Civil Rights',
#   'list_name_encoded': 'race-and-civil-rights',
#   'oldest_published_date': '2014-12-14',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Religion Spirituality and Faith',
#   'display_name': 'Religion, Spirituality and Faith',
#   'list_name_encoded': 'religion-spirituality-and-faith',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Science',
#   'display_name': 'Science',
#   'list_name_encoded': 'science',
#   'oldest_published_date': '2013-04-14',
#   'newest_published_date': '2019-09-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Sports',
#   'display_name': 'Sports and Fitness',
#   'list_name_encoded': 'sports',
#   'oldest_published_date': '2014-03-02',
#   'newest_published_date': '2019-09-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Travel',
#   'display_name': 'Travel',
#   'list_name_encoded': 'travel',
#   'oldest_published_date': '2014-09-07',
#   'newest_published_date': '2017-01-15',
#   'updated': 'MONTHLY'},
#  {'list_name': 'Young Adult Paperback Monthly',
#   'display_name': 'Young Adult Paperback',
#   'list_name_encoded': 'young-adult-paperback-monthly',
#   'oldest_published_date': '2019-10-13',
#   'newest_published_date': '2020-03-15',
#   'updated': 'MONTHLY'}]

# %% [markdown]
# ### Extracting the date and list name information
# One way to extract data and convert dates to datetime format

# %%
# aggregate all the published date values
str_dates = aggregate(listoflists,'oldest_published_date')

# %%
# Function to turn the string formatted dates to naive datetime.date representations
def str_to_date(val):
    a = val.split('-')
    b = []
    for i in a:
        b.append(int(i))
    return datetime.date(b[0],b[1],b[2])

# %%
# Store datetimes in a new list
datetimes = []
for i in str_dates:
    datetimes.append(str_to_date(i))

# %%
# The oldest entry
min(datetimes)
# Out:
# datetime.date(2008, 6, 8)

# %%
# Get list names 
list_names = aggregate(listoflists,'list_name')

# %%
# zip list name and oldest published dates for display purposes
list(zip(a,b))
# Out:
# [('2011-02-13', 'Combined Print and E-Book Fiction'),
#  ('2011-02-13', 'Combined Print and E-Book Nonfiction'),
#  ('2008-06-08', 'Hardcover Fiction'),
#  ('2008-06-08', 'Hardcover Nonfiction'),
#  ('2008-06-08', 'Trade Fiction Paperback'),
#  ('2008-06-08', 'Mass Market Paperback'),
#  ('2008-06-08', 'Paperback Nonfiction'),
#  ('2011-02-13', 'E-Book Fiction'),
#  ('2011-02-13', 'E-Book Nonfiction'),
#  ('2008-06-08', 'Hardcover Advice'),
#  ('2008-06-08', 'Paperback Advice'),
#  ('2013-04-28', 'Advice How-To and Miscellaneous'),
#  ('2009-03-15', 'Hardcover Graphic Books'),
#  ('2009-03-15', 'Paperback Graphic Books'),
#  ('2009-03-15', 'Manga'),
#  ('2011-02-13', 'Combined Print Fiction'),
#  ('2011-02-13', 'Combined Print Nonfiction'),
#  ('2008-06-08', 'Chapter Books'),
#  ('2012-12-16', 'Childrens Middle Grade'),
#  ('2015-08-30', 'Childrens Middle Grade E-Book'),
#  ('2015-08-30', 'Childrens Middle Grade Hardcover'),
#  ('2015-08-30', 'Childrens Middle Grade Paperback'),
#  ('2008-06-08', 'Paperback Books'),
#  ('2008-06-08', 'Picture Books'),
#  ('2008-06-08', 'Series Books'),
#  ('2012-12-16', 'Young Adult'),
#  ('2015-08-30', 'Young Adult E-Book'),
#  ('2015-08-30', 'Young Adult Hardcover'),
#  ('2015-08-30', 'Young Adult Paperback'),
#  ('2014-09-07', 'Animals'),
#  ('2018-03-11', 'Audio Fiction'),
#  ('2018-03-11', 'Audio Nonfiction'),
#  ('2013-11-03', 'Business Books'),
#  ('2014-09-07', 'Celebrities'),
#  ('2014-10-12', 'Crime and Punishment'),
#  ('2014-10-12', 'Culture'),
#  ('2014-10-12', 'Education'),
#  ('2014-12-14', 'Espionage'),
#  ('2014-12-14', 'Expeditions Disasters and Adventures'),
#  ('2014-10-12', 'Fashion Manners and Customs'),
#  ('2013-09-01', 'Food and Fitness'),
#  ('2014-10-12', 'Games and Activities'),
#  ('2019-10-13', 'Graphic Books and Manga'),
#  ('2011-07-03', 'Hardcover Business Books'),
#  ('2014-10-12', 'Health'),
#  ('2014-09-07', 'Humor'),
#  ('2014-12-14', 'Indigenous Americans'),
#  ('2014-09-07', 'Relationships'),
#  ('2019-10-13', 'Mass Market Monthly'),
#  ('2019-10-13', 'Middle Grade Paperback Monthly'),
#  ('2011-07-03', 'Paperback Business Books'),
#  ('2014-09-07', 'Family'),
#  ('2011-07-03', 'Hardcover Political Books'),
#  ('2014-12-14', 'Race and Civil Rights'),
#  ('2014-09-07', 'Religion Spirituality and Faith'),
#  ('2013-04-14', 'Science'),
#  ('2014-03-02', 'Sports'),
#  ('2014-09-07', 'Travel'),
#  ('2019-10-13', 'Young Adult Paperback Monthly')]

# %% [markdown]
# ### Alternativley we can just read the dictionary into a pandas dataframe

# %%
lists_df = pd.DataFrame(listoflists)
lists = lists_df['list_name_encoded'].to_list()

# %%
# function to convert the str formatted values to datetimes
def cols_to_datetime(df, list_of_cols):
    for i in list_of_cols:
        try:
            df[i]=pd.to_datetime(df[i])
        except KeyError:
            print(f'{i} is not a key in the df')
        except ValueError:
            print(f"{i} isn't in datetime format")
    pass

# %%
cols_to_datetime(lists_df,['list_name','oldest_published_date'])
# Out:
# list_name isn't in datetime format

# %%
lists[:5]
# Out:
# ['combined-print-and-e-book-fiction',
#  'combined-print-and-e-book-nonfiction',
#  'hardcover-fiction',
#  'hardcover-nonfiction',
#  'trade-fiction-paperback']

# %% [markdown]
# ## Get information from NYT API
# Here we retreive information from a specific list. the current hardcover bestsellers.

# %%
a = requests.get('https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key='+NYT_API_KEY)

# %%
b = json.loads(a.text)

# %%
# Overview of heirarchy
print('Top Level:\n',b.keys(),'\n')
print('Results:\n',b['results'].keys(),'\n')
print('Books sample:\n',b['results']['books'][0].keys())
# Out:
# Top Level:
#  dict_keys(['status', 'copyright', 'num_results', 'last_modified', 'results'])
#
# Results:
#  dict_keys(['list_name', 'list_name_encoded', 'bestsellers_date', 'published_date', 'published_date_description', 'next_published_date', 'previous_published_date', 'display_name', 'normal_list_ends_at', 'updated', 'books', 'corrections'])
#
# Books sample:
#  dict_keys(['rank', 'rank_last_week', 'weeks_on_list', 'asterisk', 'dagger', 'primary_isbn10', 'primary_isbn13', 'publisher', 'description', 'price', 'title', 'author', 'contributor', 'contributor_note', 'book_image', 'book_image_width', 'book_image_height', 'amazon_product_url', 'age_group', 'book_review_link', 'first_chapter_link', 'sunday_review_link', 'article_chapter_link', 'isbns', 'buy_links', 'book_uri'])

# %%
# Most of the relevant information is in books:
b['results']['books'][0]
# Out:
# {'rank': 1,
#  'rank_last_week': 0,
#  'weeks_on_list': 1,
#  'asterisk': 0,
#  'dagger': 0,
#  'primary_isbn10': '0805096604',
#  'primary_isbn13': '9780805096606',
#  'publisher': 'Holt',
#  'description': 'The third book in the Wolf Hall trilogy. After Anne Boleyn’s execution, Thomas Cromwell’s enemies assemble.',
#  'price': 0,
#  'title': 'THE MIRROR & THE LIGHT',
#  'author': 'Hilary Mantel',
#  'contributor': 'by Hilary Mantel',
#  'contributor_note': '',
#  'book_image': 'https://s1.nyt.com/du/books/images/9780805096606.jpg',
#  'book_image_width': 329,
#  'book_image_height': 500,
#  'amazon_product_url': 'https://www.amazon.com/dp/0805096604?tag=NYTBSREV-20&tag=NYTBS-20',
#  'age_group': '',
#  'book_review_link': '',
#  'first_chapter_link': '',
#  'sunday_review_link': '',
#  'article_chapter_link': '',
#  'isbns': [{'isbn10': '0805096604', 'isbn13': '9780805096606'},
#   {'isbn10': '1250773261', 'isbn13': '9781250773265'}],
#  'buy_links': [{'name': 'Amazon',
#    'url': 'https://www.amazon.com/dp/0805096604?tag=NYTBSREV-20&tag=NYTBS-20'},
#   {'name': 'Apple Books',
#    'url': 'https://du-gae-books-dot-nyt-du-prd.appspot.com/buy?title=THE+MIRROR+%26+THE+LIGHT&author=Hilary+Mantel'},
#   {'name': 'Barnes and Noble',
#    'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780805096606'},
#   {'name': 'Books-A-Million',
#    'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BMIRROR%2B%2526%2BTHE%2BLIGHT%2FHilary%2BMantel%2F9780805096606'},
#   {'name': 'Local Booksellers',
#    'url': 'https://www.indiebound.org/book/9780805096606?aff=NYT'}],
#  'book_uri': 'nyt://book/0fe666d7-9d07-555f-b6ba-d8b9c4b746d4'}

# %%
books = []
for i in b['results']['books']:
    books.append(i['title'])

# %%
books
# Out:
# ['WHERE THE CRAWDADS SING',
#  'AMERICAN DIRT',
#  'THE SILENT PATIENT',
#  'ONE MINUTE OUT',
#  'GOLDEN IN DEATH',
#  'THE DUTCH HOUSE',
#  'SUCH A FUN AGE',
#  'A LONG PETAL OF THE SEA',
#  'THE GUARDIANS',
#  'THE GIVER OF STARS',
#  'THE SUN DOWN MOTEL',
#  'CROOKED RIVER',
#  'THE OTHER MRS.',
#  'THE HOLDOUT',
#  'DEAR EDWARD']

# %% [markdown]
# ##  Getting all lists from a time period

# %%
lists_df.head()
# Out:
#                          display_name                             list_name  \
# 0     Combined Print & E-Book Fiction     Combined Print and E-Book Fiction
# 1  Combined Print & E-Book Nonfiction  Combined Print and E-Book Nonfiction
# 2                   Hardcover Fiction                     Hardcover Fiction
# 3                Hardcover Nonfiction                  Hardcover Nonfiction
# 4             Paperback Trade Fiction               Trade Fiction Paperback
#
#                       list_name_encoded newest_published_date  \
# 0     combined-print-and-e-book-fiction            2020-03-01
# 1  combined-print-and-e-book-nonfiction            2020-03-01
# 2                     hardcover-fiction            2020-03-01
# 3                  hardcover-nonfiction            2020-03-01
# 4               trade-fiction-paperback            2020-03-01
#
#   oldest_published_date updated
# 0            2011-02-13  WEEKLY
# 1            2011-02-13  WEEKLY
# 2            2008-06-08  WEEKLY
# 3            2008-06-08  WEEKLY
# 4            2008-06-08  WEEKLY

# %%
lists_df['book_list']=np.nan

# %%
lists_df.head()
# Out:
#                          display_name                             list_name  \
# 0     Combined Print & E-Book Fiction     Combined Print and E-Book Fiction
# 1  Combined Print & E-Book Nonfiction  Combined Print and E-Book Nonfiction
# 2                   Hardcover Fiction                     Hardcover Fiction
# 3                Hardcover Nonfiction                  Hardcover Nonfiction
# 4             Paperback Trade Fiction               Trade Fiction Paperback
#
#                       list_name_encoded newest_published_date  \
# 0     combined-print-and-e-book-fiction            2020-03-01
# 1  combined-print-and-e-book-nonfiction            2020-03-01
# 2                     hardcover-fiction            2020-03-01
# 3                  hardcover-nonfiction            2020-03-01
# 4               trade-fiction-paperback            2020-03-01
#
#   oldest_published_date updated  book_list
# 0            2011-02-13  WEEKLY        NaN
# 1            2011-02-13  WEEKLY        NaN
# 2            2008-06-08  WEEKLY        NaN
# 3            2008-06-08  WEEKLY        NaN
# 4            2008-06-08  WEEKLY        NaN

# %%
# This doesn't work, I have to figure out why.
lists_df.loc[lists_df.list_name_encoded=='hardcover-fiction','book_list'] = ['test',"this"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-479af3c3a773> in <module>
#       1 # This doesn't work, I have to figure out why.
# ----> 2 lists_df.loc[lists_df.list_name_encoded=='hardcover-fiction','book_list'] = ['test',"this"]
#
# G:\Apps\Anaconda3\envs\U4-S3-DNN\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     188             key = com.apply_if_callable(key, self.obj)
#     189         indexer = self._get_setitem_indexer(key)
# --> 190         self._setitem_with_indexer(indexer, value)
#     191
#     192     def _validate_key(self, key, axis):
#
# G:\Apps\Anaconda3\envs\U4-S3-DNN\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     609
#     610                     if len(labels) != len(value):
# --> 611                         raise ValueError('Must have equal len keys and value '
#     612                                          'when setting with an iterable')
#     613
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
lists_df.head()
# Out:
#                          display_name                             list_name  \
# 0     Combined Print & E-Book Fiction     Combined Print and E-Book Fiction
# 1  Combined Print & E-Book Nonfiction  Combined Print and E-Book Nonfiction
# 2                   Hardcover Fiction                     Hardcover Fiction
# 3                Hardcover Nonfiction                  Hardcover Nonfiction
# 4             Paperback Trade Fiction               Trade Fiction Paperback
#
#                       list_name_encoded newest_published_date  \
# 0     combined-print-and-e-book-fiction            2020-03-01
# 1  combined-print-and-e-book-nonfiction            2020-03-01
# 2                     hardcover-fiction            2020-03-01
# 3                  hardcover-nonfiction            2020-03-01
# 4               trade-fiction-paperback            2020-03-01
#
#   oldest_published_date updated  book_list
# 0            2011-02-13  WEEKLY        NaN
# 1            2011-02-13  WEEKLY        NaN
# 2            2008-06-08  WEEKLY        NaN
# 3            2008-06-08  WEEKLY        NaN
# 4            2008-06-08  WEEKLY        NaN

# %%
lists1 = lists[:2]
lists1
# Out:
# ['combined-print-and-e-book-fiction', 'combined-print-and-e-book-nonfiction']

# %% [markdown]
# ## Rate limitations
#
# NYT imposes a rate limitation of 10 calls per minute ( 6 second delay for continuous calling ) and 4000 calls a day. This is a reasonable time span, and the rate limits need to be accounted for once the program is ready to index all the data from NYT.

# %%
# Retrive information 
books_dict2 = {}
for item in lists:
    request_url="https://api.nytimes.com/svc/books/v3/lists/current/"+item+".json?api-key="+NYT_API_KEY
    results = requests.get(request_url)
    results = json.loads(results.text)
    print("status:", results['status'])
    try:
        book_list = aggregate(results['results']['books'],'title')
        books_dict2[item]=book_list
        print(item, "added")
    except KeyError:
        print(item, "NOT added")
    time.sleep(6)
# Out:
# status: OK
# combined-print-and-e-book-fiction added
# status: OK
# combined-print-and-e-book-nonfiction added
# status: OK
# hardcover-fiction added
# status: OK
# hardcover-nonfiction added
# status: OK
# trade-fiction-paperback added
# status: OK
# mass-market-paperback added
# status: OK
# paperback-nonfiction added
# status: OK
# e-book-fiction added
# status: OK
# e-book-nonfiction added
# status: OK
# hardcover-advice added
# status: OK
# paperback-advice added
# status: OK
# advice-how-to-and-miscellaneous added
# status: OK
# hardcover-graphic-books added
# status: OK
# paperback-graphic-books added
# status: OK
# manga added
# status: OK
# combined-print-fiction added
# status: OK
# combined-print-nonfiction added
# status: OK
# chapter-books added
# status: OK
# childrens-middle-grade added
# status: OK
# childrens-middle-grade-e-book added
# status: OK
# childrens-middle-grade-hardcover added
# status: OK
# childrens-middle-grade-paperback added
# status: OK
# paperback-books added
# status: OK
# picture-books added
# status: OK
# series-books added
# status: OK
# young-adult added
# status: OK
# young-adult-e-book added
# status: OK
# young-adult-hardcover added
# status: OK
# young-adult-paperback added
# status: OK
# animals added
# status: OK
# audio-fiction added
# status: OK
# audio-nonfiction added
# status: OK
# business-books added
# status: OK
# celebrities added
# status: OK
# crime-and-punishment added
# status: OK
# culture added
# status: OK
# education added
# status: OK
# espionage added
# status: OK
# expeditions-disasters-and-adventures added
# status: OK
# fashion-manners-and-customs added
# status: OK
# food-and-fitness added
# status: OK
# games-and-activities added
# status: OK
# graphic-books-and-manga added
# status: OK
# hardcover-business-books added
# status: OK
# health added
# status: OK
# humor added
# status: OK
# indigenous-americans added
# status: OK
# relationships added
# status: OK
# mass-market-monthly added
# status: OK
# middle-grade-paperback-monthly added
# status: OK
# paperback-business-books added
# status: OK
# family added
# status: OK
# hardcover-political-books added
# status: OK
# race-and-civil-rights added
# status: OK
# religion-spirituality-and-faith added
# status: OK
# science added
# status: OK
# sports added
# status: OK
# travel added
# status: OK
# young-adult-paperback-monthly added

# %%
lists[:10]
# Out:
# ['combined-print-and-e-book-fiction',
#  'combined-print-and-e-book-nonfiction',
#  'hardcover-fiction',
#  'hardcover-nonfiction',
#  'trade-fiction-paperback',
#  'mass-market-paperback',
#  'paperback-nonfiction',
#  'e-book-fiction',
#  'e-book-nonfiction',
#  'hardcover-advice']

# %%
books_dict2
# Out:
# {'combined-print-and-e-book-fiction': ['ONE MINUTE OUT',
#   'AMERICAN DIRT',
#   'WHERE THE CRAWDADS SING',
#   'LITTLE FIRES EVERYWHERE',
#   'CHASING CASSANDRA',
#   'THE SILENT PATIENT',
#   'GOLDEN IN DEATH',
#   'THE DUTCH HOUSE',
#   'THE GIVER OF STARS',
#   'THE TATTOOIST OF AUSCHWITZ',
#   'THE GUARDIANS',
#   'THE OTHER MRS.',
#   'THE OUTSIDER',
#   'SUCH A FUN AGE',
#   'A LONG PETAL OF THE SEA'],
#  'combined-print-and-e-book-nonfiction': ['THE MAMBA MENTALITY',
#   'DARK TOWERS',
#   'OPEN BOOK',
#   'A VERY STABLE GENIUS',
#   'UN-TRUMPING AMERICA',
#   'UNTIL THE END OF TIME',
#   'EDUCATED',
#   'PROFILES IN CORRUPTION',
#   'ON TYRANNY',
#   'JUST MERCY',
#   'TALKING TO STRANGERS',
#   'SAPIENS',
#   'BECOMING',
#   'THE BODY KEEPS THE SCORE',
#   'YOU NEVER FORGET YOUR FIRST'],
#  'hardcover-fiction': ['WHERE THE CRAWDADS SING',
#   'AMERICAN DIRT',
#   'THE SILENT PATIENT',
#   'ONE MINUTE OUT',
#   'GOLDEN IN DEATH',
#   'THE DUTCH HOUSE',
#   'SUCH A FUN AGE',
#   'A LONG PETAL OF THE SEA',
#   'THE GUARDIANS',
#   'THE GIVER OF STARS',
#   'THE SUN DOWN MOTEL',
#   'CROOKED RIVER',
#   'THE OTHER MRS.',
#   'THE HOLDOUT',
#   'DEAR EDWARD'],
#  'hardcover-nonfiction': ['THE MAMBA MENTALITY',
#   'DARK TOWERS',
#   'OPEN BOOK',
#   'A VERY STABLE GENIUS',
#   'UN-TRUMPING AMERICA',
#   'UNTIL THE END OF TIME',
#   'PROFILES IN CORRUPTION',
#   'EDUCATED',
#   'BECOMING',
#   'TALKING TO STRANGERS',
#   'YOU NEVER FORGET YOUR FIRST',
#   'KNOW MY NAME',
#   "WHY WE'RE POLARIZED",
#   'BROTHER & SISTER',
#   'THE BOOK OF DELIGHTS'],
#  'trade-fiction-paperback': ['LITTLE FIRES EVERYWHERE',
#   'THE TATTOOIST OF AUSCHWITZ',
#   'THE OUTSIDER',
#   'BEFORE WE WERE YOURS',
#   'NORMAL PEOPLE',
#   'THE OVERSTORY',
#   'UNSOLVED',
#   'ONE GOOD DEED',
#   "SUMMER OF '69",
#   'THE WOMAN IN THE WINDOW',
#   'WE MUST BE BRAVE',
#   'THE BOOK WOMAN OF TROUBLESOME CREEK',
#   'DAISY JONES & THE SIX',
#   'THEN SHE WAS GONE',
#   "THE HANDMAID'S TALE"],
#  'mass-market-paperback': ['SWEET TOMORROWS',
#   'THE MURDER HOUSE',
#   'APPRENTICE IN DEATH',
#   "A DOG'S PURPOSE",
#   'MULBERRY MOON',
#   'CRASH AND BURN',
#   'BREAKDOWN',
#   'THE GIRL ON THE TRAIN',
#   'THE 14TH COLONY',
#   'WYOMING BRAVE',
#   'WAR HAWK',
#   'PROPERTY OF A NOBLEWOMAN',
#   'CLAWBACK',
#   'TROUBLEMAKER',
#   'TRICKY TWENTY-TWO'],
#  'paperback-nonfiction': ['ON TYRANNY',
#   'JUST MERCY',
#   'THE BODY KEEPS THE SCORE',
#   'SAPIENS',
#   'WHITE FRAGILITY',
#   'BORN A CRIME',
#   'TO SHAKE THE SLEEPING SELF',
#   'WHY WE SLEEP',
#   'NO ONE IS TOO SMALL TO MAKE A DIFFERENCE',
#   'BRAIDING SWEETGRASS',
#   'OUTLIERS',
#   'BEING MORTAL',
#   'THINKING, FAST AND SLOW',
#   'MIDNIGHT IN CHERNOBYL',
#   'BAD BLOOD'],
#  'e-book-fiction': ['FULL PACKAGE',
#   'THE GUERNSEY LITERARY AND POTATO PEEL PIE SOCIETY',
#   'THE WHISTLER',
#   'RING OF FIRE',
#   'SMALL GREAT THINGS',
#   'SHELTER FOR ADELINE',
#   'A MAN CALLED OVE',
#   'THE MISTRESS',
#   'THE GUESTS ON SOUTH BATTERY',
#   "NO MAN'S LAND",
#   'BELOW THE BELT',
#   'CROSS THE LINE',
#   'THE DRY',
#   "A DOG'S PURPOSE",
#   'THE SLEEPWALKER'],
#  'e-book-nonfiction': ['HIDDEN FIGURES',
#   'HILLBILLY ELEGY',
#   'UNSINKABLE',
#   'THE LOST CITY OF THE MONKEY GOD',
#   'WISHFUL DRINKING',
#   'THREE DAYS IN JANUARY',
#   'KILLING THE RISING SUN',
#   'WHEN BREATH BECOMES AIR',
#   'THE UNDOING PROJECT',
#   'THE PRINCESS DIARIST',
#   'ALEXANDER HAMILTON',
#   'THE MAGNOLIA STORY',
#   'BORN A CRIME',
#   'TROUBLEMAKER',
#   'THANK YOU FOR BEING LATE'],
#  'hardcover-advice': ["IT'S ALL GOOD",
#   'THE FASTDIET',
#   'DARING GREATLY',
#   'LIFE CODE',
#   'THE TAPPING SOLUTION',
#   'SHRED: THE REVOLUTIONARY DIET',
#   'WHEAT BELLY',
#   'MAKING GOOD HABITS, BREAKING BAD HABITS',
#   'THE KEY IS LOVE',
#   'ONE THING',
#   'DECISIVE',
#   'FIRSTHAND',
#   'THE LEGEND OF ZELDA, HYRULE HISTORIA',
#   'WHEAT BELLY COOKBOOK',
#   'THE DRUNKEN BOTANIST'],
#  'paperback-advice': ['OBAMACARE SURVIVAL GUIDE',
#   'THE FIVE LOVE LANGUAGES',
#   'THE BEAUTY DETOX FOODS',
#   "WHAT TO EXPECT WHEN YOU'RE EXPECTING",
#   'THE GIFTS OF IMPERFECTION',
#   'FORKS OVER KNIVES: THE COOKBOOK',
#   'EAT TO LIVE',
#   'THE HONEST LIFE',
#   'CLEAN',
#   'THE HAPPINESS PROJECT',
#   'PRACTICAL PALEO',
#   'THE UNTETHERED SOUL',
#   'TO HEAVEN AND BACK',
#   'OUTSOURCE SMART',
#   "FROM MAMA'S TABLE TO MINE"],
#  'advice-how-to-and-miscellaneous': ['THE BOY, THE MOLE, THE FOX AND THE HORSE',
#   'THE FIVE LOVE LANGUAGES',
#   'GET OUT OF YOUR HEAD',
#   'ATOMIC HABITS',
#   'THE SUBTLE ART OF NOT GIVING A F*CK',
#   'MASTERING DIABETES',
#   '5 INGREDIENTS',
#   'DARE TO LEAD',
#   'SEE YOU ON SUNDAY',
#   'YOU ARE A BADASS'],
#  'hardcover-graphic-books': ['KINDRED',
#   'DANTDM: TRAYAURUS AND THE ENCHANTED CRYSTAL',
#   'BATMAN: THE KILLING JOKE',
#   'SNOW WHITE',
#   'THE BEST AMERICAN COMICS 2016',
#   'NATHAN HALE’S HAZARDOUS TALES: ALAMO ALL–STARS',
#   'ROLLING BLACKOUTS: DISPATCHES FROM TURKEY, SYRIA AND IRAQ',
#   'STAR WARS: THE ORIGINAL TRILOGY',
#   'ONE HUNDRED NIGHTS OF HERO',
#   'FIGHT CLUB 2'],
#  'paperback-graphic-books': ['GHOSTS',
#   'DRAMA',
#   'SMILE',
#   'MARCH: BOOK 1',
#   'LOVE IS LOVE',
#   'FUN HOME',
#   'PERSEPOLIS',
#   'SISTERS',
#   "THE BABY-SITTERS CLUB GRAPHIX: KRISTY'S GREAT IDEA",
#   'ROLLER GIRL'],
#  'manga': ['THE LEGEND OF ZELDA: LEGENDARY EDITION, VOL. 2',
#   'ONE-PUNCH MAN, VOL. 10',
#   "THE ANCIENT MAGUS' BRIDE, VOL. 6",
#   'TOKYO GHOUL, VOL. 1',
#   'THE LEGEND OF ZELDA: LEGENDARY EDITION, VOL. 1',
#   'SERAPH OF THE END, VOL. 11',
#   'TOKYO GHOUL, VOL. 10',
#   'ONE-PUNCH MAN, VOL. 1',
#   'DEATH NOTE BLACK, VOL. 1',
#   'ATTACK ON TITAN, VOL. 20'],
#  'combined-print-fiction': ['THE HIT',
#   'WHISKEY BEACH',
#   'FLY AWAY',
#   'PARIS',
#   'LIFE AFTER LIFE',
#   'BEAUTIFUL RUINS',
#   'WEDDING NIGHT',
#   "DADDY'S GONE A HUNTING",
#   'GONE GIRL',
#   'THE BEST OF ME',
#   'A GAME OF THRONES',
#   'WORLD WAR Z',
#   'FIFTY SHADES OF GREY',
#   'THE BLACK BOX',
#   'THE BURGESS BOYS',
#   'THE MYSTERY WOMAN',
#   "DON'T GO",
#   'CALICO JOE',
#   'THE FORGOTTEN',
#   'THE INTERESTINGS'],
#  'combined-print-nonfiction': ["LET'S EXPLORE DIABETES WITH OWLS",
#   'LEAN IN',
#   'PROOF OF HEAVEN',
#   'COOKED',
#   'WILD',
#   'TRIDENT K9 WARRIORS',
#   'WAKING UP IN HEAVEN',
#   'AMERICA THE BEAUTIFUL',
#   'DIRTY WARS',
#   'CARRIE AND ME',
#   'AMERICAN SNIPER',
#   'MY NEXT STEP',
#   'QUIET',
#   'THE NEW DIGITAL AGE',
#   'WAY OF THE KNIFE',
#   'GULP',
#   'DUCK COMMANDERS',
#   'THINKING, FAST AND SLOW',
#   "I'LL SEE YOU AGAIN",
#   'UNBROKEN'],
#  'chapter-books': ['LEGO NINJAGO CHARACTER ENCYCLOPEDIA',
#   "LINCOLN'S LAST DAYS",
#   'THE FAULT IN OUR STARS',
#   'THE LEGO IDEAS BOOK',
#   '‘WHO COULD THAT BE AT THIS HOUR?’',
#   'WONDER',
#   'THE DEMIGOD DIARIES',
#   'INSURGENT',
#   'THE LEGO BOOK',
#   'LEGO STAR WARS CHARACTER ENCYCLOPEDIA'],
#  'childrens-middle-grade': ['THE ISLE OF THE LOST',
#   'WONDER',
#   "MAL'S SPELL BOOK",
#   'DESCENDANTS',
#   'A LONG WALK TO WATER',
#   'MAX',
#   'THE CARE AND KEEPING OF YOU',
#   'THE PRINCESS IN BLACK',
#   'COUNTING BY 7s',
#   'JURASSIC WORLD',
#   "HITLER'S LAST DAYS",
#   'SERAFINA AND THE BLACK CLOAK',
#   'THE ONE AND ONLY IVAN',
#   'OUT OF MY MIND',
#   'GOODBYE STRANGER'],
#  'childrens-middle-grade-e-book': ['THE HAMMER OF THOR',
#   'WONDER',
#   'THE HIDDEN ORACLE',
#   'THE SWORD OF SUMMER',
#   'THE FINISHER'],
#  'childrens-middle-grade-hardcover': ['EPOCA: THE TREE OF ECROF',
#   'LEGACY AND THE QUEEN',
#   'THE WIZENARD: TRAINING CAMP',
#   'WONDER',
#   'LITTLE LEADERS',
#   'LITTLE LEGENDS: EXCEPTIONAL MEN IN BLACK HISTORY',
#   'DIARY OF AN AWESOME FRIENDLY KID',
#   'REFUGEE',
#   'THE COMPLETE COOKBOOK FOR YOUNG CHEFS',
#   'ALI CROSS'],
#  'childrens-middle-grade-paperback': ['HIDDEN FIGURES',
#   'A LONG WALK TO WATER',
#   'THE ONE AND ONLY IVAN',
#   'STORY THIEVES',
#   "PERCY JACKSON'S GREEK GODS",
#   'SERAFINA AND THE BLACK CLOAK',
#   'ESCAPE FROM MR. LEMONCELLO’S LIBRARY',
#   'THE WAR THAT SAVED MY LIFE',
#   'BROWN GIRL DREAMING',
#   'OUT OF MY MIND'],
#  'paperback-books': ['THE PERKS OF BEING A WALLFLOWER',
#   'ONE DIRECTION: DARE TO DREAM',
#   'DIVERGENT',
#   'LOOKING FOR ALASKA',
#   'MIDDLE SCHOOL, THE WORST YEARS OF MY LIFE',
#   'THE BOOK THIEF',
#   'THIRTEEN REASONS WHY',
#   'THE ABSOLUTELY TRUE DIARY OF A PART-TIME INDIAN',
#   'WILDWOOD',
#   'OUT OF MY MIND'],
#  'picture-books': ['HOW TO CATCH A UNICORN',
#   'HAIR LOVE',
#   'THE UNDEFEATED',
#   'DRAGONS LOVE TACOS',
#   'THE DAY THE CRAYONS QUIT',
#   'HOW TO CATCH A LEPRECHAUN',
#   'THE WONDERFUL THINGS YOU WILL BE',
#   'I AM ENOUGH',
#   'THE BOOK WITH NO PICTURES',
#   'DEAR GIRL'],
#  'series-books': ['DOG MAN',
#   'DIARY OF A WIMPY KID',
#   'HARRY POTTER',
#   "TO ALL THE BOYS I'VE LOVED BEFORE",
#   'THE BAD GUYS',
#   'WHO WAS/IS . . . ?',
#   'CAPTAIN UNDERPANTS',
#   'WINGS OF FIRE',
#   'DORK DIARIES',
#   'BABY-SITTERS CLUB GRAPHIX'],
#  'young-adult': ['PAPER TOWNS',
#   'LOOKING FOR ALASKA',
#   'ME AND EARL AND THE DYING GIRL',
#   'THE BOOK THIEF',
#   "MISS PEREGRINE'S HOME FOR PECULIAR CHILDREN",
#   'THE FAULT IN OUR STARS',
#   'THE ABSOLUTELY TRUE DIARY OF A PART-TIME INDIAN',
#   'AN ABUNDANCE OF KATHERINES',
#   'ELEANOR AND PARK',
#   'THIRTEEN REASONS WHY',
#   'THE 5TH WAVE',
#   'HOLLOW CITY',
#   'WILL GRAYSON, WILL GRAYSON',
#   'IF I STAY',
#   'RED QUEEN'],
#  'young-adult-e-book': ['BURNING GLASS',
#   'FLAMECASTER',
#   'MISTRUST',
#   'AND I DARKEN',
#   'WINDWITCH'],
#  'young-adult-hardcover': ["A GOOD GIRL'S GUIDE TO MURDER",
#   'ONE OF US IS NEXT',
#   'CHILDREN OF VIRTUE AND VENGEANCE',
#   'ONE OF US IS LYING',
#   'THE HATE U GIVE',
#   "THE QUEEN'S ASSASSIN",
#   'INFINITY SON',
#   'CHILDREN OF BLOOD AND BONE',
#   'YES NO MAYBE SO',
#   'FIVE FEET APART'],
#  'young-adult-paperback': ['THE BOOK THIEF',
#   'A MONSTER CALLS',
#   'THIRTEEN REASONS WHY',
#   'THE ABSOLUTELY TRUE DIARY OF A PART-TIME INDIAN',
#   'RED QUEEN',
#   "FIVE NIGHTS AT FREDDY'S: THE SILVER EYES",
#   'THE CABIN',
#   'BEFORE I FALL',
#   'THE CELLAR',
#   'PASSENGER'],
#  'animals': ['I COULD PEE ON THIS',
#   'LET ME TELL YOU ABOUT JASPER ...',
#   'H IS FOR HAWK',
#   'THE SOUL OF AN OCTOPUS',
#   'THE EIGHTY-DOLLAR CHAMPION',
#   'THE GENIUS OF BIRDS',
#   'THE LION IN THE LIVING ROOM',
#   'RESCUE ME',
#   'A STREET CAT NAMED BOB',
#   'REALLY IMPORTANT STUFF MY DOG HAS TAUGHT ME'],
#  'audio-fiction': ['THE LAST WISH',
#   'WHERE THE CRAWDADS SING',
#   'THE GIVER OF STARS',
#   'BLOOD OF ELVES',
#   'THE DUTCH HOUSE',
#   'AMERICAN DIRT',
#   'SUCH A FUN AGE',
#   'THE GUARDIANS',
#   'SWORD OF DESTINY',
#   'THE SILENT PATIENT',
#   'THE OUTSIDER',
#   'THE TIME OF CONTEMPT',
#   'THE THINGS WE CANNOT SAY',
#   'NORSE MYTHOLOGY',
#   'THE MARTIAN'],
#  'audio-nonfiction': ['TALKING TO STRANGERS',
#   'A VERY STABLE GENIUS',
#   'BECOMING',
#   'EDUCATED',
#   'MAYBE YOU SHOULD TALK TO SOMEONE',
#   'CATCH AND KILL',
#   'EXTREME OWNERSHIP',
#   'PROFILES IN CORRUPTION',
#   'BORN A CRIME',
#   'SAPIENS',
#   'OUTLIERS',
#   'JUST MERCY',
#   'THE BODY KEEPS THE SCORE',
#   'EMPIRE OF THE SUMMER MOON',
#   'WHY WE SLEEP'],
#  'business-books': ['LEADERSHIP STRATEGY AND TACTICS',
#   'ATOMIC HABITS',
#   'DARE TO LEAD',
#   'THE RIDE OF A LIFETIME',
#   'PRINCIPLES',
#   'OUTLIERS',
#   'THE INFINITE GAME',
#   'EXTREME OWNERSHIP',
#   'RANGE',
#   'THINKING, FAST AND SLOW'],
#  'celebrities': ['THE MAGNOLIA STORY',
#   'BORN TO RUN',
#   'SETTLE FOR MORE',
#   'TALKING AS FAST AS I CAN',
#   'BORN A CRIME',
#   'THE DAILY SHOW (THE BOOK)',
#   'THE GIRL WITH THE LOWER BACK TATTOO',
#   'SCRAPPY LITTLE NOBODY',
#   'THE PRINCESS DIARIST',
#   'SUPERFICIAL'],
#  'crime-and-punishment': ['THE DEVIL IN THE WHITE CITY',
#   'JUST MERCY',
#   'FILTHY RICH',
#   'MY OWN WORDS',
#   'NOTORIOUS RBG',
#   'THE MIDNIGHT ASSASSIN',
#   "ADNAN'S STORY",
#   'ORANGE IS THE NEW BLACK',
#   'RED NOTICE',
#   'SISTERS IN LAW'],
#  'culture': ['HAMILTON: THE REVOLUTION',
#   'BORN A CRIME',
#   'THE DAILY SHOW (THE BOOK)',
#   'THE CASE OF BEASTS',
#   'HUMANS OF NEW YORK: STORIES',
#   'SAPIENS',
#   'HUMANS OF NEW YORK',
#   'AT THE EXISTENTIALIST CAFE',
#   'SPQR',
#   'SPEAKING AMERICAN'],
#  'education': ['THINKING, FAST AND SLOW',
#   'GRIT',
#   'THING EXPLAINER',
#   'SPEAKING AMERICAN',
#   'I AM MALALA',
#   'ON WRITING',
#   'WEAPONS OF MATH DESTRUCTION',
#   'BEST AMERICAN NONREQUIRED READING 2016',
#   'HOW NOT TO BE WRONG',
#   'OTHER-WORDLY'],
#  'espionage': ['ROGUE HEROES',
#   'THE SECRET HISTORY OF WORLD WAR II',
#   "GEORGE WASHINGTON'S SECRET SIX",
#   'THE SECRET WAR',
#   'SECRET SERVICE DOGS',
#   'THE PIGEON TUNNEL',
#   'RED NOTICE',
#   'THE BILLION DOLLAR SPY',
#   'AVENUE OF SPIES',
#   "THE SPY WHO COULDN'T SPELL"],
#  'expeditions-disasters-and-adventures': ['ATLAS OBSCURA',
#   'DEAD WAKE',
#   'SULLY',
#   'WILD',
#   'BARBARIAN DAYS',
#   'THE INVENTION OF NATURE',
#   'THE WRIGHT BROTHERS',
#   'IN THE HEART OF THE SEA',
#   'THE OREGON TRAIL',
#   'PACIFIC'],
#  'fashion-manners-and-customs': ['GOOP CLEAN BEAUTY',
#   'PRIMATES OF PARK AVENUE',
#   'HOW TO TIE A SCARF',
#   'JOHN DERIAN PICTURE BOOK',
#   'A FIELD GUIDE TO REDHEADS',
#   'DOMINO',
#   'UNMENTIONABLE',
#   'PEACOCK AND VINE',
#   'MIDCENTURY CHRISTMAS',
#   'EMPIRE OF COTTON'],
#  'food-and-fitness': ['COOKING FOR JEFFREY',
#   'APPETITES',
#   'THUG KITCHEN',
#   'CRAVINGS',
#   'THE WHOLE30 COOKBOOK',
#   'SKINNYTASTE FAST AND SLOW',
#   'THE WHOLE30',
#   'THE LOSE YOUR BELLY DIET',
#   'THE FOOD LAB',
#   'ALTON BROWN:  EVERYDAYCOOK'],
#  'games-and-activities': ['STRESS RELIEF COLORING BOOK',
#   'THE LEGO IDEAS BOOK',
#   'HARRY POTTER COLORING BOOK',
#   "PLAYER'S HANDBOOK",
#   'SECRET GARDEN',
#   'ENCHANTED FOREST',
#   'LOST OCEAN',
#   'MONSTER MANUAL',
#   'CREATIVE HAVEN DAZZLING DOGS COLORING BOOK',
#   'DOCTOR WHO COLORING BOOK'],
#  'graphic-books-and-manga': ['GUTS',
#   'STRANGE PLANET',
#   'FGTEEV PRESENTS: INTO THE GAME!',
#   "BABY-SITTERS LITTLE SISTER: KAREN'S WITCH",
#   'BEST FRIENDS',
#   'DRAMA',
#   'WATCHMEN',
#   'MY HERO ACADEMIA, VOL. 1',
#   'NEW KID',
#   'SISTERS',
#   'PERSEPOLIS',
#   'SMILE',
#   'THE LEGEND OF ZELDA: TWILIGHT PRINCESS, VOL. 6',
#   'DEMON SLAYER: KIMETSU NO YAIBA, VOL. 10',
#   'BOWIE: STARDUST, RAYGUNS, & MOONAGE DAYDREAMS'],
#  'hardcover-business-books': ['LEAN IN',
#   'DUCK COMMANDERS',
#   'BEFORE HAPPINESS',
#   'LOOPTAIL',
#   'GREAT WORK',
#   'MISSION IN A BOTTLE',
#   'SYSTEM',
#   'YOU FIRST',
#   'VALUE OF DEBT',
#   'THE POWER OF HABIT',
#   'STRENGTHS-BASED LEADERSHIP',
#   'TOTAL MONEY MAKEOVER',
#   'WINNING FROM WITHIN',
#   'LEAN STARTUP',
#   '4-HOUR WORKWEEK'],
#  'health': ['WHEN BREATH BECOMES AIR',
#   'THE SUBTLE ART OF NOT GIVING A F*CK',
#   'THE WHOLE30 COOKBOOK',
#   'THE LOSE YOUR BELLY DIET',
#   'THE GENE',
#   'MEDICAL MEDIUM LIFE-CHANGING FOODS',
#   'GREEN SMOOTHIES FOR LIFE',
#   'THE ZERO SUGAR DIET',
#   '10-DAY GREEN SMOOTHIE CLEANSE',
#   'BEING MORTAL'],
#  'humor': ['TALKING AS FAST AS I CAN',
#   'BORN A CRIME',
#   'THE DAILY SHOW (THE BOOK)',
#   'THE GIRL WITH THE LOWER BACK TATTOO',
#   'SCRAPPY LITTLE NOBODY',
#   'SUPERFICIAL',
#   'WISHFUL DRINKING',
#   'GO THE -- TO SLEEP',
#   'WHY NOT ME?',
#   "KATHY GRIFFIN'S CELEBRITY RUN-INS"],
#  'indigenous-americans': ['THE HEART OF EVERYTHING THAT IS',
#   'EMPIRE OF THE SUMMER MOON',
#   'BURY MY HEART AT WOUNDED KNEE',
#   'CRAZY HORSE AND CUSTER',
#   'HISTORY OF THE INDIAN TRIBES OF NORTH AMERICA'],
#  'relationships': ['THE UNDOING PROJECT',
#   'THE FIVE LOVE LANGUAGES',
#   'UNINVITED',
#   'DARING GREATLY',
#   'WHY NOT ME?',
#   'LOVE WARRIOR',
#   'MODERN ROMANCE',
#   'BAD FEMINIST',
#   'TRIBE',
#   'MEN EXPLAIN THINGS TO ME'],
#  'mass-market-monthly': ['VENDETTA IN DEATH',
#   'THE BOY',
#   'THE FIRST LADY',
#   'PIECES OF HER',
#   'CUT AND RUN',
#   'SILENT NIGHT',
#   'HUCKLEBERRY LAKE',
#   'THE COMING STORM',
#   'THE BEST OF US',
#   'THE MALTA EXCHANGE',
#   'CEMETERY ROAD',
#   'THE 13-MINUTE MURDER',
#   'VENDETTA ROAD',
#   "PREACHER'S FRENZY",
#   'WOLF PACK'],
#  'middle-grade-paperback-monthly': ['A LONG WALK TO WATER',
#   'THE ONE AND ONLY IVAN',
#   'THE GIRL WHO DRANK THE MOON',
#   'OUT OF MY MIND',
#   'THE UNTEACHABLES',
#   'I AM MALALA',
#   'PAX',
#   'RESTART',
#   'INSIDE OUT AND BACK AGAIN',
#   'NEVERMOOR: THE TRIALS OF MORRIGAN CROW'],
#  'paperback-business-books': ['OUTLIERS',
#   'THINKING, FAST AND SLOW',
#   'STEVE JOBS',
#   'CONVERT EVERY CLICK',
#   'TIPPING POINT',
#   'HEADS IN BEDS',
#   'DRIVE',
#   'FREAKONOMICS',
#   'THE CHECKLIST MANIFESTO',
#   'WHY NATIONS FAIL'],
#  'family': ['GO THE -- TO SLEEP',
#   "WHAT TO EXPECT WHEN YOU'RE EXPECTING",
#   'LOVE WARRIOR',
#   'LUCKY BASTARD',
#   'GOODNIGHT DARTH VADER',
#   'THE 36-HOUR DAY',
#   'DARTH VADER AND SON',
#   'H IS FOR HAWK',
#   'MOTHER, CAN YOU NOT?',
#   'GIRLS AND SEX'],
#  'hardcover-political-books': ['KILLING THE RISING SUN',
#   'HILLBILLY ELEGY',
#   'SETTLE FOR MORE',
#   'THANK YOU FOR BEING LATE',
#   'ALL THE GALLANT MEN',
#   'OUR REVOLUTION',
#   'BETWEEN THE WORLD AND ME',
#   'WHITE TRASH',
#   'THE NEW JIM CROW',
#   'JUST MERCY'],
#  'race-and-civil-rights': ['BORN A CRIME',
#   'HIDDEN FIGURES',
#   'BETWEEN THE WORLD AND ME',
#   'THE NEW JIM CROW',
#   'JUST MERCY',
#   'MARCH TRILOGY',
#   'MARCH: BOOK 1',
#   'MISADVENTURES OF AWKWARD BLACK GIRL',
#   "YOU CAN'T TOUCH MY HAIR",
#   'STAMPED FROM THE BEGINNING'],
#  'religion-spirituality-and-faith': ['SHAKEN',
#   'THE BOOK OF JOY',
#   'THINK BETTER, LIVE BETTER',
#   'THE FOUR AGREEMENTS',
#   'UNINVITED',
#   'THE BROKEN WAY',
#   'THE BOOK OF MYSTERIES',
#   'PRESENT OVER PERFECT',
#   'THE POWER OF NOW',
#   'THE AMERICAN MIRACLE'],
#  'science': ['SAPIENS',
#   'THE BODY KEEPS THE SCORE',
#   'BEING MORTAL',
#   'THINKING, FAST AND SLOW',
#   'THE MOSQUITO',
#   'THE IMMORTAL LIFE OF HENRIETTA LACKS',
#   'DOPESICK',
#   'WHY WE SLEEP',
#   '21 LESSONS FOR THE 21ST CENTURY',
#   'QUIET'],
#  'sports': ['RANGE',
#   'SHOE DOG',
#   'THE SIXTH MAN',
#   'THE BOYS IN THE BOAT',
#   'NEVER SETTLE',
#   'WOLFPACK',
#   'BARBARIAN DAYS',
#   'IF THESE WALLS COULD TALK',
#   'FOR THE GOOD OF THE GAME',
#   'ALL THE WAY'],
#  'travel': ['ATLAS OBSCURA',
#   'HUMANS OF NEW YORK: STORIES',
#   'THE ROAD TO LITTLE DRIBBLING',
#   'HUMANS OF NEW YORK',
#   'SULLY',
#   'DESTINATIONS OF A LIFETIME',
#   'SPEAKING AMERICAN',
#   'WILD',
#   'LION',
#   'NONSTOP METROPOLIS'],
#  'young-adult-paperback-monthly': ['DEAR MARTIN',
#   'LONG WAY DOWN',
#   'THE BOOK THIEF',
#   'THE BOY IN THE STRIPED PAJAMAS',
#   'THE LOST',
#   'LOOKING FOR ALASKA',
#   'THE LIBRARIAN OF AUSCHWITZ',
#   'I AM NOT YOUR PERFECT MEXICAN DAUGHTER',
#   'JUST MERCY',
#   'THE SUN IS ALSO A STAR']}

# %%
request_url="https://api.nytimes.com/svc/books/v3/lists/current/hardcover-political-books.json?api-key=76quqESu9qYqfKpEfnJou4kpY1uJ9pMV"
results = requests.get(request_url)
results = json.loads(results.text)

# %%
aggregate(results['results']['books'],'title')

# %%
results['status']

# %%
df = pd.DataFrame(columns=['test'])
df['test']=lists

# %%
df

# %% [markdown]
# Basic Features:
#
# - Title
# - Author
#     - Gender
#     - Nationality
#     - Languages Spoken By author (at time of writing)
# - Genre
# - Publisher
# - Published year
# - Published in
#     - (country, state city?)
# - Pages
# - Sales Data
# - Original Language
#
# Possible Engineered Features:
#
# - popularity
# - Combined Rating Weighed from different sources
# - NLP
#     - publisher site information
#     - book author information
#     - Reviews (from one or several sources)
#     - Book wiki page
#     - Author wiki page
#     - Reddit information
#     - books reddit search results + sentiment analysis on results
# - does reddit exist
# - does wiki exist
# - does fandom exist
# - twitter mentions
# - google mentions
# - NN on book cover
